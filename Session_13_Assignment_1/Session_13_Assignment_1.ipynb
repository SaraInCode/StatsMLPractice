# %% [markdown]
# ## 1. Create an sqlalchemy engine using a sample from the data set

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
a_data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",header=None)
a_data.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
rename_col = ['age','workclass','fnlwgt','education','education_num','marital_status',
           'occupation','relationship','race','sex','capital_gain','capital_loss',
           'hours_per_week','native_country', 'income']

# %%
a_data.columns = rename_col
a_data.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
engine = create_engine('sqlite://', echo=False)

# %%
a_data.to_sql("adult",  con=engine, if_exists="replace",index=False)

# %% [markdown]
# ## 2. Write two basic update queries

# %%
engine.execute('''update adult set "education" ="Bachelors" where "education"=" Undergraduate" ''')

# %%
engine.execute('''update adult set "marital_status" ="Single" where "marital_status"=" Never-married" ''')

# %% [markdown]
# ## 3. Write two delete queries

# %%
engine.execute('''delete from adult where education_num=7 ''')

# %%
engine.execute('''delete from adult where education_num<5 ''')

# %% [markdown]
# ## 4. Write two filter queries

# %%
filter1 = engine.execute('''select * from adult where age<20''')

for row in filter1:
    print (row)
# Out:
# (19, ' Private', 168294, ' HS-grad', 9, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 544091, ' HS-grad', 9, ' Married-AF-spouse', ' Adm-clerical', ' Wife', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 226956, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' ?', ' <=50K')
# (19, ' Private', 101509, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 32, ' United-States', ' <=50K')
# (18, ' Private', 446839, ' HS-grad', 9, 'Single', ' Sales', ' Not-in-family', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' ?', 304873, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Female', 34095, 0, 32, ' United-States', ' <=50K')
# (19, ' Private', 301606, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 316868, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' Mexico', ' <=50K')
# (18, ' Private', 183930, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' ?', 170653, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' Italy', ' <=50K')
# (18, ' Private', 243313, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Local-gov', 27382, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' ?', 218956, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 24, ' Canada', ' <=50K')
# (17, ' Private', 191260, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 1055, 0, 24, ' United-States', ' <=50K')
# (19, ' ?', 860348, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' Black', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 104112, ' HS-grad', 9, 'Single', ' Sales', ' Unmarried', ' Black', ' Male', 0, 0, 30, ' Haiti', ' <=50K')
# (19, ' Private', 25429, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 232392, ' HS-grad', 9, 'Single', ' Other-service', ' Other-relative', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 206399, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 211870, ' 9th', 5, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 6, ' United-States', ' <=50K')
# (19, ' Private', 249609, ' Some-college', 10, 'Single', ' Protective-serv', ' Own-child', ' White', ' Male', 0, 0, 8, ' United-States', ' <=50K')
# (18, ' ?', 165532, ' 12th', 8, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 217039, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 28, ' United-States', ' <=50K')
# (17, ' Private', 169658, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 21, ' United-States', ' <=50K')
# (19, ' Private', 262601, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 14, ' United-States', ' <=50K')
# (17, ' Private', 102726, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 475028, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' State-gov', 378418, ' HS-grad', 9, 'Single', ' Tech-support', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 192453, ' Some-college', 10, 'Single', ' Other-service', ' Other-relative', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (17, ' Private', 316929, ' 12th', 8, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 231193, ' 12th', 8, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 196061, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 33, ' United-States', ' <=50K')
# (17, ' Private', 32607, ' 10th', 6, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 376540, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' ?', 52114, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 293227, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 45, ' United-States', ' <=50K')
# (18, ' Private', 177722, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 117201, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' ?', 241616, ' HS-grad', 9, 'Single', ' ?', ' Unmarried', ' White', ' Male', 0, 2001, 40, ' United-States', ' <=50K')
# (19, ' Self-emp-not-inc', 36012, ' Some-college', 10, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Local-gov', 167816, ' HS-grad', 9, ' Divorced', ' Exec-managerial', ' Not-in-family', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' ?', 80710, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 194608, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 187161, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 240747, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Female', 0, 0, 40, ' Dominican-Republic', ' <=50K')
# (17, ' ?', 138507, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 119075, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' ?', 194095, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Federal-gov', 234151, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Unmarried', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' ?', 172582, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' Private', 213644, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 169882, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 594, 0, 15, ' United-States', ' <=50K')
# (17, ' ?', 333100, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 1055, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 225775, ' Some-college', 10, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Local-gov', 32124, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 9, ' United-States', ' <=50K')
# (17, ' Private', 163494, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 130806, ' 10th', 6, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (18, ' Private', 208447, ' 12th', 8, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 6, ' United-States', ' <=50K')
# (19, ' ?', 62534, ' Bachelors', 13, 'Single', ' ?', ' Own-child', ' Black', ' Female', 0, 0, 40, ' Jamaica', ' <=50K')
# (19, ' Private', 124265, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 323421, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 214617, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 375077, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (18, ' Private', 46247, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 197384, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (17, ' ?', 158762, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' ?', 228373, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 418324, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 36, ' United-States', ' <=50K')
# (19, ' ?', 263338, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 45, ' United-States', ' <=50K')
# (19, ' Private', 286469, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 152545, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 8, ' United-States', ' <=50K')
# (19, ' Private', 365640, ' HS-grad', 9, 'Single', ' Priv-house-serv', ' Not-in-family', ' White', ' Female', 0, 0, 45, ' ?', ' <=50K')
# (19, ' ?', 33487, ' Some-college', 10, 'Single', ' ?', ' Other-relative', ' Amer-Indian-Eskimo', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Self-emp-not-inc', 60116, ' 10th', 6, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Private', 354104, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 125010, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 45, ' United-States', ' <=50K')
# (17, ' ?', 103810, ' 12th', 8, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 242941, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 1602, 10, ' United-States', ' <=50K')
# (17, ' Private', 329783, ' 10th', 6, 'Single', ' Sales', ' Other-relative', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 201901, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Female', 0, 1719, 15, ' United-States', ' <=50K')
# (19, ' Private', 43285, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 675421, ' 9th', 5, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 594, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 172893, ' Some-college', 10, 'Single', ' Exec-managerial', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 343059, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 55284, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 171306, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 3, ' United-States', ' <=50K')
# (19, ' ?', 356717, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' ?', 143867, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Local-gov', 134935, ' 12th', 8, 'Single', ' Protective-serv', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' ?', 192773, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 129059, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' Black', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 446219, ' 10th', 6, 'Single', ' Sales', ' Unmarried', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 80616, ' 10th', 6, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 27, ' United-States', ' <=50K')
# (19, ' Private', 57067, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Other-relative', ' White', ' Male', 0, 0, 45, ' United-States', ' <=50K')
# (19, ' Private', 196857, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 115248, ' Some-college', 10, 'Single', ' Adm-clerical', ' Not-in-family', ' Asian-Pac-Islander', ' Male', 0, 0, 40, ' Vietnam', ' <=50K')
# (18, ' Private', 280298, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 24, ' United-States', ' <=50K')
# (18, ' Private', 57413, ' Some-college', 10, ' Divorced', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 280071, ' Some-college', 10, 'Single', ' Machine-op-inspct', ' Other-relative', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' Private', 87653, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 116562, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 387568, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Local-gov', 36411, ' 12th', 8, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' ?', 179715, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Federal-gov', 30559, ' HS-grad', 9, ' Married-AF-spouse', ' Sales', ' Wife', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 206010, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 8, ' United-States', ' <=50K')
# (19, ' Private', 89397, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 297396, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' ?', 145234, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 130849, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' Private', 266287, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (18, ' Private', 179203, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 181546, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' ?', 110998, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' Asian-Pac-Islander', ' Female', 0, 0, 40, ' Philippines', ' <=50K')
# (19, ' Private', 417657, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' Private', 383637, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 40425, ' Some-college', 10, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 28, ' United-States', ' <=50K')
# (18, ' Private', 97963, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 25429, ' Some-college', 10, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (17, ' Private', 139183, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' ?', 139003, ' HS-grad', 9, 'Single', ' ?', ' Other-relative', ' Other', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (18, ' Private', 43272, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 89478, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 188618, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (17, ' Private', 263746, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (18, ' Private', 174732, ' HS-grad', 9, 'Single', ' Other-service', ' Other-relative', ' Black', ' Male', 0, 0, 36, ' United-States', ' <=50K')
# (19, ' ?', 37332, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 1055, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 100999, ' Bachelors', 13, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 182355, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' Black', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 130125, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' Amer-Indian-Eskimo', ' Female', 1055, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 354201, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 104704, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Self-emp-not-inc', 206599, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 22, ' United-States', ' <=50K')
# (18, ' ?', 298133, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 148644, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 28, ' United-States', ' <=50K')
# (19, ' Private', 202673, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' Private', 52372, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 423863, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 38619, ' Some-college', 10, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 66, ' United-States', ' <=50K')
# (19, ' Private', 306467, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 174233, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' Black', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (18, ' ?', 437851, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 251579, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 14, ' United-States', ' <=50K')
# (19, ' State-gov', 73009, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 376240, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 42, ' United-States', ' <=50K')
# (19, ' ?', 35507, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 45, ' United-States', ' <=50K')
# (19, ' Private', 246652, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 263024, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 387215, ' Some-college', 10, 'Single', ' Tech-support', ' Own-child', ' White', ' Male', 0, 1719, 16, ' United-States', ' <=50K')
# (19, ' ?', 208874, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 129010, ' 12th', 8, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 127388, ' 12th', 8, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 152182, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 184710, ' Some-college', 10, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 80163, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 63574, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (17, ' Private', 160118, ' 12th', 8, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 10, ' ?', ' <=50K')
# (19, ' Private', 406078, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' ?', 20469, ' HS-grad', 9, 'Single', ' ?', ' Other-relative', ' Asian-Pac-Islander', ' Female', 0, 0, 12, ' South', ' <=50K')
# (19, ' Private', 246226, ' HS-grad', 9, 'Single', ' Craft-repair', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 167147, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 184759, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Female', 0, 0, 26, ' United-States', ' <=50K')
# (19, ' Private', 39026, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 353358, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (18, ' Private', 301948, ' HS-grad', 9, 'Single', ' Protective-serv', ' Own-child', ' White', ' Male', 34095, 0, 3, ' United-States', ' <=50K')
# (19, ' Private', 299050, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 124884, ' 9th', 5, 'Single', ' ?', ' Not-in-family', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 146378, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 40, ' ?', ' <=50K')
# (18, ' Private', 57957, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 386378, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 278870, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (18, ' Private', 168288, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Self-emp-not-inc', 40293, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Other-relative', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 57324, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 291429, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 194059, ' 12th', 8, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' ?', 139183, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 29250, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Federal-gov', 27433, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 30246, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 121037, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' ?', 163788, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 120283, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 24, ' United-States', ' <=50K')
# (17, ' ?', 127003, ' 9th', 5, 'Single', ' ?', ' Own-child', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 156501, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 16, ' United-States', ' <=50K')
# (17, ' Private', 137042, ' 10th', 6, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 300379, ' 12th', 8, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 42750, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Not-in-family', ' White', ' Male', 0, 0, 55, ' United-States', ' <=50K')
# (19, ' Private', 125591, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 165115, ' HS-grad', 9, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 169853, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 571853, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Local-gov', 169853, ' HS-grad', 9, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Never-worked', 206359, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 327434, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 308064, ' HS-grad', 9, 'Single', ' ?', ' Not-in-family', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 23233, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 237455, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 218956, ' HS-grad', 9, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' State-gov', 156294, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Self-emp-not-inc', 30800, ' 10th', 6, ' Married-spouse-absent', ' Adm-clerical', ' Unmarried', ' Amer-Indian-Eskimo', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 227491, ' HS-grad', 9, 'Single', ' Sales', ' Not-in-family', ' Asian-Pac-Islander', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 57206, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' ?', 279288, ' 10th', 6, 'Single', ' ?', ' Other-relative', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 63363, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 129620, ' 10th', 6, 'Single', ' Other-service', ' Other-relative', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' State-gov', 165289, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 120029, ' Some-college', 10, 'Single', ' Adm-clerical', ' Other-relative', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 415354, ' 10th', 6, ' Divorced', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' Private', 221403, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 18, ' United-States', ' <=50K')
# (17, ' Private', 27032, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 170720, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 391329, ' Some-college', 10, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 50879, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 6, ' United-States', ' <=50K')
# (19, ' Private', 167140, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 1602, 24, ' United-States', ' <=50K')
# (18, ' Private', 110230, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 11, ' United-States', ' <=50K')
# (19, ' Private', 414871, ' HS-grad', 9, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 121240, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 310158, ' Some-college', 10, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 78817, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 141868, ' HS-grad', 9, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' State-gov', 112432, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Private', 375114, ' HS-grad', 9, 'Single', ' Craft-repair', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 71792, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' Asian-Pac-Islander', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 185695, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 401051, ' 10th', 6, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 160033, ' Some-college', 10, 'Single', ' Protective-serv', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 215190, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 169324, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 302859, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 226980, ' 12th', 8, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 17, ' United-States', ' <=50K')
# (19, ' Private', 121972, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 257750, ' Some-college', 10, 'Single', ' Sales', ' Other-relative', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 178811, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 334427, ' 10th', 6, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 36, ' United-States', ' <=50K')
# (19, ' Private', 277974, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 38294, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Other-relative', ' White', ' Male', 2597, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 195985, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 50, ' United-States', ' <=50K')
# (18, ' ?', 128538, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 6, ' United-States', ' <=50K')
# (19, ' Private', 131615, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 214617, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 387641, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 283945, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 120251, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 14, ' United-States', ' <=50K')
# (19, ' Private', 217418, ' Some-college', 10, 'Single', ' Adm-clerical', ' Other-relative', ' Black', ' Female', 0, 0, 38, ' United-States', ' <=50K')
# (18, ' Private', 118376, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (17, ' Private', 130795, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' ?', 202516, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 235849, ' HS-grad', 9, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 365613, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 10, ' Canada', ' <=50K')
# (19, ' ?', 371827, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' Portugal', ' <=50K')
# (17, ' Private', 100828, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 138153, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Private', 206874, ' Assoc-voc', 11, 'Single', ' Adm-clerical', ' Own-child', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 151506, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 183041, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' ?', 201299, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 229745, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 156587, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 38, ' United-States', ' <=50K')
# (18, ' Private', 716066, ' 10th', 6, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 188815, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 34095, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 266635, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 260801, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 226913, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 144161, ' HS-grad', 9, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 192399, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 60, ' United-States', ' <=50K')
# (18, ' Private', 116528, ' Some-college', 10, 'Single', ' Craft-repair', ' Not-in-family', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 393712, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 186159, ' Some-college', 10, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 135924, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' ?', 80564, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 60, ' United-States', ' <=50K')
# (19, ' Private', 331556, ' 10th', 6, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 120544, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' ?', 47713, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' ?', 204441, ' HS-grad', 9, 'Single', ' ?', ' Other-relative', ' Black', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 164395, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 91928, ' Some-college', 10, 'Single', ' Other-service', ' Other-relative', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 221129, ' 9th', 5, ' Married-civ-spouse', ' Other-service', ' Husband', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 118847, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 301762, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 374262, ' 12th', 8, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 423024, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 165310, ' HS-grad', 9, ' Married-civ-spouse', ' Machine-op-inspct', ' Other-relative', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 165754, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 118352, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 281704, ' Some-college', 10, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 186067, ' 10th', 6, 'Single', ' Tech-support', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' ?', 26620, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 127190, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 318822, ' Some-college', 10, 'Single', ' Adm-clerical', ' Other-relative', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 271521, ' HS-grad', 9, 'Single', ' Other-service', ' Other-relative', ' Asian-Pac-Islander', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 136866, ' HS-grad', 9, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 45, ' United-States', ' <=50K')
# (17, ' State-gov', 117906, ' 10th', 6, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 215463, ' 12th', 8, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 164320, ' HS-grad', 9, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 269657, ' Some-college', 10, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 389755, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 351040, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 40, ' Puerto-Rico', ' <=50K')
# (18, ' Private', 181755, ' HS-grad', 9, 'Single', ' Sales', ' Not-in-family', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 208463, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 231962, ' HS-grad', 9, 'Single', ' Other-service', ' Unmarried', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 70982, ' Assoc-voc', 11, 'Single', ' Other-service', ' Own-child', ' Asian-Pac-Islander', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (18, ' ?', 256191, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' Black', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 183258, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 263340, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' Private', 141918, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 22, ' United-States', ' <=50K')
# (18, ' Private', 39529, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 32, ' United-States', ' <=50K')
# (18, ' Private', 135315, ' 9th', 5, 'Single', ' Sales', ' Own-child', ' Other', ' Female', 0, 0, 32, ' United-States', ' <=50K')
# (19, ' Private', 240468, ' Some-college', 10, ' Married-spouse-absent', ' Sales', ' Own-child', ' White', ' Female', 0, 1602, 40, ' United-States', ' <=50K')
# (19, ' ?', 217769, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 594, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 142751, ' 10th', 6, 'Single', ' Handlers-cleaners', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 427862, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 294485, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Local-gov', 292962, ' HS-grad', 9, 'Single', ' Craft-repair', ' Other-relative', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 156874, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 27, ' United-States', ' <=50K')
# (18, ' ?', 276864, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 1602, 20, ' United-States', ' <=50K')
# (17, ' Private', 154908, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Self-emp-not-inc', 212207, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 11, ' United-States', ' <=50K')
# (18, ' ?', 274746, ' HS-grad', 9, 'Single', ' ?', ' Unmarried', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 112432, ' HS-grad', 9, ' Married-civ-spouse', ' Handlers-cleaners', ' Husband', ' White', ' Male', 0, 0, 58, ' United-States', ' <=50K')
# (18, ' Private', 163332, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 22, ' United-States', ' <=50K')
# (18, ' Private', 395567, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' State-gov', 354104, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Private', 169758, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (18, ' Self-emp-inc', 119422, ' HS-grad', 9, 'Single', ' Other-service', ' Unmarried', ' Asian-Pac-Islander', ' Female', 0, 0, 30, ' India', ' <=50K')
# (19, ' ?', 180976, ' 10th', 6, 'Single', ' ?', ' Unmarried', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' ?', 369678, ' HS-grad', 9, 'Single', ' ?', ' Not-in-family', ' Other', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 163787, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 199441, ' HS-grad', 9, 'Single', ' Prof-specialty', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 123416, ' 12th', 8, ' Separated', ' Prof-specialty', ' Own-child', ' White', ' Female', 1055, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 69927, ' HS-grad', 9, ' Married-civ-spouse', ' Other-service', ' Wife', ' Black', ' Female', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Without-pay', 344858, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 268276, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 145844, ' Assoc-acdm', 12, 'Single', ' Exec-managerial', ' Not-in-family', ' White', ' Female', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' ?', 233779, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 60, ' United-States', ' <=50K')
# (19, ' Private', 250639, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 302945, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 10, ' Thailand', ' <=50K')
# (18, ' ?', 85154, ' 12th', 8, 'Single', ' ?', ' Own-child', ' Asian-Pac-Islander', ' Female', 0, 0, 24, ' Germany', ' <=50K')
# (18, ' ?', 97318, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 158343, ' Some-college', 10, 'Single', ' Tech-support', ' Own-child', ' White', ' Female', 0, 0, 40, ' ?', ' <=50K')
# (17, ' ?', 406920, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 115215, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 46162, ' HS-grad', 9, 'Single', ' Farming-fishing', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 418176, ' HS-grad', 9, 'Single', ' Exec-managerial', ' Not-in-family', ' Black', ' Male', 0, 0, 32, ' United-States', ' <=50K')
# (19, ' ?', 57329, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 30, ' Japan', ' <=50K')
# (19, ' ?', 369527, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 264924, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# ...
# (19, ' State-gov', 127085, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 152044, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 3, ' United-States', ' <=50K')
# (19, ' State-gov', 60412, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (17, ' Private', 184924, ' 9th', 5, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 1719, 15, ' United-States', ' <=50K')
# (18, ' Private', 232082, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 122775, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 136363, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Local-gov', 243960, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 16, ' United-States', ' <=50K')
# (18, ' Private', 152246, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' Asian-Pac-Islander', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (19, ' Private', 333953, ' 12th', 8, 'Single', ' Other-service', ' Other-relative', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' State-gov', 135162, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' ?', 28455, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Self-emp-inc', 170125, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 215110, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 121788, ' Some-college', 10, 'Single', ' Sales', ' Not-in-family', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 199480, ' 10th', 6, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 292583, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 112795, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' ?', 351195, ' 9th', 5, 'Single', ' ?', ' Other-relative', ' White', ' Male', 0, 1719, 35, ' El-Salvador', ' <=50K')
# (17, ' Private', 132680, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 1602, 10, ' United-States', ' <=50K')
# (18, ' Private', 194561, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 166153, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (19, ' Private', 96176, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 39756, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 174732, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 174394, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' ?', 113915, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' Black', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (18, ' Private', 165532, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 15, ' United-States', ' <=50K')
# (17, ' ?', 34019, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 189924, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 229431, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 11, ' United-States', ' <=50K')
# (18, ' Private', 285013, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 10, ' United-States', ' <=50K')
# (19, ' Private', 355477, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 115815, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' Private', 128617, ' 10th', 6, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 26, ' United-States', ' <=50K')
# (18, ' Private', 337046, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' State-gov', 261422, ' Some-college', 10, 'Single', ' Prof-specialty', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (17, ' ?', 371316, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 208366, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 237646, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 51574, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' Asian-Pac-Islander', ' Female', 0, 1602, 38, ' United-States', ' <=50K')
# (17, ' Private', 143868, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' ?', 245274, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 16, ' United-States', ' <=50K')
# (18, ' Private', 240330, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 18, ' United-States', ' <=50K')
# (18, ' ?', 157131, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (18, ' Private', 206008, ' Some-college', 10, 'Single', ' Sales', ' Unmarried', ' White', ' Male', 2176, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 198943, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 45381, ' Some-college', 10, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 8, ' United-States', ' <=50K')
# (19, ' Local-gov', 354104, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 79682, ' 10th', 6, 'Single', ' Priv-house-serv', ' Other-relative', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 169155, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (18, ' Private', 110142, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 182643, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 9, ' United-States', ' <=50K')
# (19, ' Private', 178811, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Own-child', ' Black', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' ?', 267399, ' 12th', 8, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (17, ' Local-gov', 192387, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 45, ' United-States', ' <=50K')
# (18, ' Private', 174926, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 15, ' ?', ' <=50K')
# (19, ' Private', 100009, ' HS-grad', 9, 'Single', ' Craft-repair', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 207173, ' HS-grad', 9, ' Separated', ' Adm-clerical', ' Unmarried', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 194561, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 37, ' United-States', ' <=50K')
# (19, ' Private', 301911, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' Asian-Pac-Islander', ' Male', 0, 0, 35, ' Laos', ' <=50K')
# (18, ' Private', 225859, ' Some-college', 10, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 2907, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 160049, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' Private', 117444, ' HS-grad', 9, 'Single', ' Craft-repair', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 141626, ' Some-college', 10, 'Single', ' Tech-support', ' Own-child', ' White', ' Male', 2176, 0, 20, ' United-States', ' <=50K')
# (17, ' ?', 172145, ' 10th', 6, 'Single', ' ?', ' Own-child', ' Black', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 166153, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 56613, ' Some-college', 10, 'Single', ' Protective-serv', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 124265, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 50, ' United-States', ' <=50K')
# (19, ' ?', 230874, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 89760, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 35065, ' HS-grad', 9, 'Single', ' Transport-moving', ' Not-in-family', ' Black', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (18, ' Private', 231562, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 33, ' United-States', ' <=50K')
# (18, ' Private', 210311, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 160811, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 38, ' United-States', ' <=50K')
# (18, ' Private', 94196, ' HS-grad', 9, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 188568, ' Some-college', 10, 'Single', ' Priv-house-serv', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 36882, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 261720, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Private', 37720, ' 10th', 6, 'Single', ' Machine-op-inspct', ' Own-child', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (18, ' Self-emp-inc', 174202, ' HS-grad', 9, 'Single', ' Transport-moving', ' Own-child', ' White', ' Male', 0, 0, 60, ' United-States', ' <=50K')
# (17, ' Private', 309504, ' 10th', 6, 'Single', ' Sales', ' Unmarried', ' White', ' Female', 0, 0, 24, ' United-States', ' <=50K')
# (19, ' Private', 194260, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (17, ' ?', 171461, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 257980, ' HS-grad', 9, 'Single', ' Machine-op-inspct', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' ?', 166018, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 183532, ' Some-college', 10, 'Single', ' Handlers-cleaners', ' Own-child', ' White', ' Male', 0, 0, 25, ' United-States', ' <=50K')
# (17, ' ?', 256173, ' 10th', 6, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 292590, ' HS-grad', 9, ' Married-civ-spouse', ' Sales', ' Other-relative', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (19, ' Private', 237848, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 3, ' United-States', ' <=50K')
# (19, ' Private', 223669, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (17, ' Private', 214787, ' 12th', 8, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Private', 157273, ' 10th', 6, 'Single', ' Other-service', ' Other-relative', ' Black', ' Male', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' Private', 183824, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' ?', 90230, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')
# (18, ' Private', 218889, ' 9th', 5, 'Single', ' Other-service', ' Own-child', ' Black', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (17, ' Private', 24090, ' HS-grad', 9, 'Single', ' Exec-managerial', ' Own-child', ' White', ' Female', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 28790, ' Some-college', 10, 'Single', ' Other-service', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 251579, ' Some-college', 10, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 14, ' United-States', ' <=50K')
# (18, ' ?', 97474, ' HS-grad', 9, 'Single', ' ?', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 167087, ' HS-grad', 9, 'Single', ' Adm-clerical', ' Not-in-family', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 119964, ' HS-grad', 9, 'Single', ' Craft-repair', ' Other-relative', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (19, ' Private', 127491, ' HS-grad', 9, 'Single', ' Other-service', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
# (19, ' Private', 128363, ' Some-college', 10, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 30, ' United-States', ' <=50K')
# (18, ' Private', 119655, ' 12th', 8, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 0, 12, ' United-States', ' <=50K')
# (19, ' ?', 204868, ' HS-grad', 9, ' Married-civ-spouse', ' ?', ' Wife', ' White', ' Female', 0, 0, 36, ' United-States', ' <=50K')
# (19, ' Private', 693066, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 15, ' United-States', ' <=50K')
# (18, ' Private', 180039, ' 12th', 8, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 0, 20, ' United-States', ' <=50K')
# (19, ' Private', 57145, ' HS-grad', 9, 'Single', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 25, ' United-States', ' <=50K')
# (18, ' Never-worked', 153663, ' Some-college', 10, 'Single', ' ?', ' Own-child', ' White', ' Male', 0, 0, 4, ' United-States', ' <=50K')
# (18, ' Private', 347336, ' 12th', 8, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 12, ' United-States', ' <=50K')
# (18, ' Private', 200047, ' 12th', 8, 'Single', ' Adm-clerical', ' Own-child', ' White', ' Male', 0, 0, 35, ' United-States', ' <=50K')
# (19, ' Private', 60890, ' HS-grad', 9, 'Single', ' Craft-repair', ' Not-in-family', ' White', ' Male', 0, 0, 49, ' United-States', ' <=50K')
# (18, ' Private', 41381, ' HS-grad', 9, 'Single', ' Sales', ' Own-child', ' White', ' Female', 0, 1602, 20, ' United-States', ' <=50K')
# (17, ' Private', 117798, ' 10th', 6, 'Single', ' Other-service', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K')

# %%
filter2 = engine.execute('''select age,sex from adult where marital_status=" Divorced"''')

for row in filter2:
    print (row)
# Out:
# (38, ' Male')
# (43, ' Female')
# (59, ' Female')
# (39, ' Male')
# (45, ' Male')
# (44, ' Female')
# (50, ' Male')
# (47, ' Male')
# (29, ' Male')
# (28, ' Female')
# (44, ' Female')
# (53, ' Female')
# (37, ' Female')
# (28, ' Female')
# (48, ' Female')
# (39, ' Male')
# (46, ' Female')
# (43, ' Female')
# (47, ' Female')
# (52, ' Male')
# (29, ' Male')
# (44, ' Female')
# (36, ' Female')
# (43, ' Female')
# (41, ' Female')
# (53, ' Female')
# (38, ' Female')
# (36, ' Male')
# (37, ' Female')
# (35, ' Male')
# (50, ' Female')
# (60, ' Female')
# (65, ' Female')
# (41, ' Female')
# (33, ' Female')
# (38, ' Male')
# (36, ' Female')
# (30, ' Female')
# (34, ' Female')
# (60, ' Female')
# (50, ' Male')
# (31, ' Female')
# (37, ' Female')
# (38, ' Male')
# (43, ' Female')
# (36, ' Female')
# (35, ' Male')
# (30, ' Female')
# (43, ' Male')
# (57, ' Female')
# (39, ' Female')
# (46, ' Male')
# (54, ' Male')
# (46, ' Female')
# (45, ' Female')
# (34, ' Female')
# (41, ' Female')
# (33, ' Female')
# (35, ' Male')
# (34, ' Female')
# (29, ' Male')
# (45, ' Female')
# (52, ' Male')
# (67, ' Female')
# (45, ' Female')
# (46, ' Male')
# (34, ' Female')
# (41, ' Female')
# (58, ' Female')
# (39, ' Female')
# (28, ' Male')
# (24, ' Male')
# (44, ' Male')
# (74, ' Female')
# (46, ' Male')
# (33, ' Female')
# (47, ' Male')
# (36, ' Female')
# (57, ' Male')
# (52, ' Female')
# (26, ' Male')
# (31, ' Female')
# (42, ' Female')
# (48, ' Male')
# (34, ' Female')
# (46, ' Female')
# (44, ' Female')
# (36, ' Female')
# (36, ' Female')
# (55, ' Female')
# (34, ' Male')
# (47, ' Female')
# (31, ' Male')
# (23, ' Male')
# (36, ' Female')
# (42, ' Female')
# (43, ' Male')
# (31, ' Female')
# (43, ' Male')
# (25, ' Male')
# (41, ' Female')
# (43, ' Male')
# (40, ' Female')
# (26, ' Female')
# (48, ' Male')
# (38, ' Female')
# (49, ' Female')
# (29, ' Female')
# (48, ' Female')
# (47, ' Male')
# (46, ' Female')
# (37, ' Male')
# (37, ' Male')
# (38, ' Male')
# (42, ' Male')
# (31, ' Female')
# (54, ' Female')
# (40, ' Female')
# (43, ' Male')
# (44, ' Male')
# (33, ' Male')
# (32, ' Female')
# (36, ' Female')
# (34, ' Male')
# (63, ' Female')
# (47, ' Female')
# (44, ' Male')
# (45, ' Male')
# (48, ' Male')
# (51, ' Female')
# (22, ' Male')
# (34, ' Female')
# (43, ' Female')
# (28, ' Male')
# (38, ' Male')
# (41, ' Female')
# (36, ' Female')
# (19, ' Female')
# (38, ' Male')
# (34, ' Male')
# (43, ' Female')
# (34, ' Female')
# (34, ' Female')
# (45, ' Female')
# (48, ' Female')
# (41, ' Male')
# (34, ' Female')
# (42, ' Male')
# (40, ' Female')
# (33, ' Female')
# (40, ' Male')
# (51, ' Female')
# (40, ' Female')
# (51, ' Male')
# (49, ' Female')
# (37, ' Male')
# (31, ' Female')
# (33, ' Female')
# (31, ' Male')
# (50, ' Female')
# (52, ' Female')
# (49, ' Male')
# (52, ' Female')
# (44, ' Male')
# (42, ' Female')
# (51, ' Female')
# (71, ' Female')
# (47, ' Male')
# (51, ' Female')
# (49, ' Female')
# (41, ' Female')
# (32, ' Female')
# (40, ' Male')
# (59, ' Female')
# (50, ' Female')
# (42, ' Female')
# (37, ' Male')
# (59, ' Female')
# (32, ' Male')
# (41, ' Female')
# (38, ' Male')
# (25, ' Male')
# (25, ' Male')
# (40, ' Male')
# (49, ' Female')
# (38, ' Female')
# (57, ' Female')
# (37, ' Male')
# (26, ' Female')
# (35, ' Female')
# (49, ' Male')
# (44, ' Male')
# (47, ' Female')
# (30, ' Female')
# (33, ' Male')
# (37, ' Female')
# (48, ' Female')
# (50, ' Female')
# (26, ' Female')
# (44, ' Male')
# (39, ' Male')
# (51, ' Male')
# (28, ' Male')
# (57, ' Female')
# (50, ' Male')
# (58, ' Female')
# (67, ' Female')
# (27, ' Female')
# (52, ' Female')
# (59, ' Female')
# (39, ' Female')
# (43, ' Male')
# (37, ' Female')
# (53, ' Female')
# (44, ' Male')
# (37, ' Female')
# (29, ' Female')
# (22, ' Female')
# (39, ' Female')
# (42, ' Female')
# (31, ' Female')
# (38, ' Male')
# (44, ' Male')
# (29, ' Male')
# (45, ' Male')
# (38, ' Male')
# (37, ' Female')
# (60, ' Female')
# (47, ' Male')
# (41, ' Female')
# (46, ' Female')
# (40, ' Female')
# (43, ' Male')
# (52, ' Female')
# (52, ' Male')
# (48, ' Female')
# (51, ' Male')
# (37, ' Female')
# (45, ' Female')
# (42, ' Female')
# (30, ' Male')
# (28, ' Male')
# (23, ' Male')
# (36, ' Female')
# (46, ' Male')
# (30, ' Female')
# (26, ' Male')
# (45, ' Female')
# (41, ' Male')
# (43, ' Male')
# (24, ' Female')
# (57, ' Female')
# (29, ' Female')
# (39, ' Male')
# (53, ' Female')
# (50, ' Male')
# (44, ' Male')
# (51, ' Male')
# (32, ' Male')
# (35, ' Female')
# (53, ' Male')
# (47, ' Female')
# (60, ' Female')
# (34, ' Male')
# (51, ' Female')
# (42, ' Male')
# (35, ' Male')
# (56, ' Female')
# (47, ' Female')
# (30, ' Female')
# (37, ' Male')
# (45, ' Female')
# (41, ' Female')
# (42, ' Female')
# (52, ' Female')
# (31, ' Male')
# (32, ' Male')
# (64, ' Female')
# (41, ' Male')
# (46, ' Male')
# (47, ' Male')
# (39, ' Female')
# (53, ' Female')
# (43, ' Female')
# (63, ' Female')
# (58, ' Male')
# (64, ' Female')
# (39, ' Female')
# (46, ' Female')
# (31, ' Male')
# (38, ' Male')
# (46, ' Male')
# (56, ' Female')
# (31, ' Female')
# (43, ' Male')
# (26, ' Male')
# (32, ' Male')
# (32, ' Male')
# (27, ' Female')
# (34, ' Female')
# (20, ' Female')
# (42, ' Male')
# (34, ' Male')
# (36, ' Female')
# (44, ' Male')
# (54, ' Female')
# (29, ' Female')
# (46, ' Female')
# (48, ' Female')
# (37, ' Female')
# (31, ' Male')
# (46, ' Male')
# (48, ' Female')
# (46, ' Female')
# (42, ' Male')
# (55, ' Female')
# (54, ' Female')
# (36, ' Male')
# (38, ' Male')
# (52, ' Female')
# (42, ' Male')
# (43, ' Male')
# (41, ' Female')
# (38, ' Female')
# (35, ' Female')
# (59, ' Female')
# (46, ' Male')
# (48, ' Female')
# (51, ' Female')
# (50, ' Female')
# (35, ' Female')
# (37, ' Female')
# (45, ' Female')
# (24, ' Female')
# (34, ' Male')
# (42, ' Female')
# (48, ' Female')
# (40, ' Female')
# (49, ' Male')
# (18, ' Male')
# (50, ' Male')
# (40, ' Female')
# (56, ' Male')
# (40, ' Female')
# (46, ' Female')
# (39, ' Female')
# (42, ' Male')
# (51, ' Male')
# (45, ' Female')
# (49, ' Female')
# (58, ' Female')
# (42, ' Male')
# (57, ' Female')
# (47, ' Male')
# (55, ' Male')
# (34, ' Female')
# (24, ' Female')
# (32, ' Female')
# (41, ' Female')
# (27, ' Male')
# (40, ' Male')
# (43, ' Male')
# (44, ' Male')
# (55, ' Female')
# (34, ' Male')
# (34, ' Female')
# (41, ' Female')
# (22, ' Male')
# (40, ' Male')
# (28, ' Female')
# (45, ' Female')
# (30, ' Male')
# (41, ' Female')
# (45, ' Female')
# (34, ' Female')
# (22, ' Female')
# (33, ' Female')
# (38, ' Female')
# (56, ' Male')
# (52, ' Female')
# (40, ' Female')
# (35, ' Male')
# (34, ' Male')
# (29, ' Male')
# (40, ' Female')
# (28, ' Female')
# (62, ' Male')
# (37, ' Female')
# (33, ' Female')
# (37, ' Female')
# (49, ' Male')
# (40, ' Male')
# (42, ' Female')
# (54, ' Male')
# (48, ' Female')
# (40, ' Female')
# (36, ' Male')
# (34, ' Male')
# (35, ' Female')
# (44, ' Female')
# (46, ' Female')
# (45, ' Female')
# (22, ' Female')
# (54, ' Female')
# (42, ' Female')
# (37, ' Female')
# (32, ' Female')
# (43, ' Male')
# (36, ' Male')
# (33, ' Female')
# (28, ' Male')
# (47, ' Male')
# (44, ' Male')
# (52, ' Female')
# (47, ' Male')
# (31, ' Male')
# (45, ' Female')
# (58, ' Female')
# (45, ' Female')
# (43, ' Female')
# (31, ' Female')
# (37, ' Female')
# (50, ' Male')
# (58, ' Female')
# (39, ' Female')
# (32, ' Female')
# (59, ' Female')
# (34, ' Female')
# (53, ' Female')
# (57, ' Female')
# (40, ' Female')
# (40, ' Female')
# (39, ' Male')
# (53, ' Female')
# (40, ' Female')
# (59, ' Male')
# (41, ' Male')
# (49, ' Female')
# (31, ' Male')
# (43, ' Female')
# (27, ' Female')
# (40, ' Female')
# (23, ' Male')
# (52, ' Female')
# (39, ' Female')
# (62, ' Female')
# (55, ' Female')
# (47, ' Female')
# (32, ' Female')
# (39, ' Female')
# (39, ' Female')
# (67, ' Female')
# (51, ' Male')
# (30, ' Female')
# (51, ' Male')
# (34, ' Female')
# (54, ' Female')
# (25, ' Female')
# (30, ' Female')
# (37, ' Male')
# (30, ' Female')
# (41, ' Male')
# (32, ' Female')
# (31, ' Male')
# (37, ' Female')
# (31, ' Male')
# (53, ' Female')
# (48, ' Female')
# (30, ' Male')
# (36, ' Female')
# (58, ' Male')
# (34, ' Female')
# (41, ' Male')
# (30, ' Male')
# (29, ' Female')
# (32, ' Female')
# (29, ' Female')
# (39, ' Female')
# (55, ' Female')
# (51, ' Female')
# (40, ' Female')
# (63, ' Male')
# (51, ' Female')
# (47, ' Male')
# (38, ' Female')
# (46, ' Female')
# (54, ' Female')
# (49, ' Male')
# (55, ' Female')
# (29, ' Female')
# (51, ' Female')
# (48, ' Female')
# (51, ' Male')
# (36, ' Male')
# (27, ' Female')
# (26, ' Male')
# (50, ' Male')
# (57, ' Female')
# (48, ' Female')
# (52, ' Male')
# (53, ' Female')
# (46, ' Female')
# (38, ' Male')
# (42, ' Female')
# (29, ' Female')
# (42, ' Female')
# (52, ' Female')
# (43, ' Male')
# (59, ' Male')
# (36, ' Male')
# (48, ' Male')
# (50, ' Female')
# (49, ' Male')
# (52, ' Male')
# (64, ' Female')
# (59, ' Female')
# (28, ' Male')
# (37, ' Female')
# (31, ' Female')
# (26, ' Female')
# (28, ' Female')
# (35, ' Male')
# (44, ' Female')
# (57, ' Female')
# (28, ' Male')
# (31, ' Male')
# (51, ' Female')
# (58, ' Male')
# (41, ' Female')
# (33, ' Female')
# (59, ' Female')
# (28, ' Female')
# (37, ' Female')
# (33, ' Male')
# (46, ' Male')
# (43, ' Male')
# (38, ' Female')
# (54, ' Female')
# (24, ' Female')
# (38, ' Female')
# (30, ' Male')
# (52, ' Female')
# (33, ' Male')
# (46, ' Female')
# (28, ' Male')
# (46, ' Female')
# (50, ' Female')
# (30, ' Female')
# (59, ' Female')
# (64, ' Female')
# (41, ' Male')
# (35, ' Female')
# (41, ' Male')
# (32, ' Female')
# (38, ' Female')
# (38, ' Male')
# (42, ' Male')
# (43, ' Female')
# (44, ' Female')
# (46, ' Male')
# (52, ' Female')
# (46, ' Female')
# (66, ' Female')
# (33, ' Male')
# (48, ' Female')
# (35, ' Male')
# (63, ' Male')
# (40, ' Female')
# (28, ' Male')
# (50, ' Male')
# (49, ' Female')
# (52, ' Female')
# (24, ' Female')
# (38, ' Male')
# (35, ' Male')
# (43, ' Female')
# (40, ' Male')
# (40, ' Female')
# (52, ' Male')
# (56, ' Male')
# (31, ' Male')
# (26, ' Male')
# (29, ' Female')
# (37, ' Female')
# (35, ' Female')
# (43, ' Female')
# (46, ' Female')
# (37, ' Female')
# (28, ' Female')
# (63, ' Female')
# (25, ' Female')
# (33, ' Female')
# (40, ' Male')
# (33, ' Female')
# (36, ' Female')
# (48, ' Female')
# (43, ' Female')
# (39, ' Female')
# (43, ' Female')
# (36, ' Female')
# (25, ' Male')
# (66, ' Female')
# (48, ' Female')
# (35, ' Female')
# (55, ' Female')
# (33, ' Male')
# (40, ' Female')
# (26, ' Male')
# (32, ' Male')
# (39, ' Female')
# (55, ' Female')
# (43, ' Male')
# (51, ' Male')
# (62, ' Female')
# (50, ' Female')
# (54, ' Female')
# (31, ' Male')
# (65, ' Male')
# (66, ' Female')
# (44, ' Female')
# (36, ' Male')
# (40, ' Male')
# (69, ' Female')
# (56, ' Female')
# (47, ' Female')
# (47, ' Male')
# (42, ' Female')
# (81, ' Female')
# (57, ' Male')
# (68, ' Female')
# (33, ' Female')
# (47, ' Female')
# (42, ' Male')
# (35, ' Female')
# (48, ' Male')
# (44, ' Male')
# (32, ' Male')
# (60, ' Female')
# (36, ' Female')
# (45, ' Male')
# (33, ' Male')
# (47, ' Male')
# (56, ' Male')
# (44, ' Female')
# (27, ' Female')
# (25, ' Female')
# (44, ' Female')
# (42, ' Female')
# (35, ' Female')
# (40, ' Male')
# (35, ' Female')
# (38, ' Male')
# (33, ' Female')
# (39, ' Female')
# (40, ' Male')
# (57, ' Female')
# (51, ' Female')
# (41, ' Female')
# (54, ' Female')
# (67, ' Female')
# (41, ' Female')
# (36, ' Female')
# (43, ' Male')
# (43, ' Female')
# (42, ' Female')
# (53, ' Female')
# (61, ' Female')
# (52, ' Male')
# (48, ' Male')
# (30, ' Female')
# (35, ' Female')
# (42, ' Female')
# (38, ' Male')
# (23, ' Female')
# (40, ' Male')
# (77, ' Male')
# (41, ' Male')
# (42, ' Male')
# (40, ' Female')
# (40, ' Female')
# (49, ' Female')
# (47, ' Female')
# (28, ' Female')
# (31, ' Female')
# (49, ' Female')
# (61, ' Male')
# (35, ' Male')
# (31, ' Female')
# (35, ' Male')
# (32, ' Female')
# (35, ' Female')
# (60, ' Female')
# (50, ' Female')
# (33, ' Female')
# (53, ' Female')
# (44, ' Female')
# (56, ' Female')
# (33, ' Male')
# (32, ' Male')
# (45, ' Female')
# (47, ' Female')
# (49, ' Male')
# (44, ' Male')
# (37, ' Male')
# (35, ' Male')
# (41, ' Female')
# (55, ' Female')
# (43, ' Male')
# (43, ' Female')
# (56, ' Male')
# (60, ' Male')
# (55, ' Female')
# (43, ' Female')
# (42, ' Female')
# (26, ' Female')
# (33, ' Male')
# (30, ' Male')
# (27, ' Female')
# (44, ' Male')
# (55, ' Female')
# (35, ' Female')
# (44, ' Female')
# (36, ' Female')
# (35, ' Female')
# (47, ' Male')
# (48, ' Female')
# (34, ' Female')
# (46, ' Male')
# (45, ' Male')
# (53, ' Male')
# (40, ' Female')
# (38, ' Female')
# (41, ' Female')
# (59, ' Male')
# (63, ' Female')
# (30, ' Female')
# (37, ' Female')
# (40, ' Male')
# (45, ' Male')
# (46, ' Female')
# (47, ' Female')
# (46, ' Female')
# (42, ' Female')
# (37, ' Female')
# (41, ' Female')
# (52, ' Female')
# (27, ' Female')
# (19, ' Female')
# (42, ' Female')
# (27, ' Male')
# (39, ' Female')
# (44, ' Male')
# (49, ' Male')
# (37, ' Male')
# (30, ' Male')
# (39, ' Male')
# (48, ' Male')
# (59, ' Male')
# (42, ' Male')
# (55, ' Male')
# (57, ' Female')
# (42, ' Male')
# (44, ' Female')
# (53, ' Male')
# (45, ' Male')
# (32, ' Female')
# (44, ' Male')
# (37, ' Female')
# (43, ' Male')
# (44, ' Female')
# (35, ' Female')
# (40, ' Male')
# (44, ' Female')
# (50, ' Male')
# (31, ' Male')
# (57, ' Male')
# (56, ' Male')
# (33, ' Male')
# (43, ' Female')
# (45, ' Male')
# (42, ' Female')
# (56, ' Male')
# (35, ' Female')
# (40, ' Female')
# (47, ' Female')
# (23, ' Male')
# (34, ' Female')
# (30, ' Female')
# (31, ' Male')
# (58, ' Female')
# (38, ' Male')
# (58, ' Female')
# (51, ' Male')
# (46, ' Male')
# (57, ' Female')
# (53, ' Male')
# (55, ' Male')
# (70, ' Female')
# (56, ' Female')
# (32, ' Female')
# (33, ' Male')
# (54, ' Male')
# (24, ' Female')
# (47, ' Female')
# (42, ' Female')
# (31, ' Female')
# (38, ' Male')
# (53, ' Male')
# (24, ' Female')
# (70, ' Female')
# (32, ' Female')
# (50, ' Male')
# (40, ' Female')
# (41, ' Female')
# (34, ' Female')
# (36, ' Male')
# (42, ' Female')
# (42, ' Female')
# (37, ' Female')
# (29, ' Male')
# (37, ' Female')
# (61, ' Male')
# (51, ' Female')
# (55, ' Female')
# (40, ' Female')
# (54, ' Male')
# (37, ' Male')
# (54, ' Female')
# (51, ' Female')
# (51, ' Female')
# (47, ' Female')
# (53, ' Female')
# (39, ' Male')
# (39, ' Male')
# (36, ' Female')
# (38, ' Male')
# (33, ' Male')
# (40, ' Female')
# (51, ' Male')
# (30, ' Female')
# (49, ' Male')
# (44, ' Male')
# (75, ' Male')
# (53, ' Female')
# (25, ' Female')
# (43, ' Female')
# (34, ' Female')
# (25, ' Female')
# (45, ' Female')
# (56, ' Male')
# (38, ' Female')
# (46, ' Female')
# (43, ' Male')
# (34, ' Male')
# (31, ' Female')
# (38, ' Female')
# (38, ' Female')
# (33, ' Male')
# (34, ' Male')
# (36, ' Female')
# (42, ' Female')
# (48, ' Male')
# (41, ' Male')
# (31, ' Male')
# (39, ' Male')
# (31, ' Male')
# (54, ' Male')
# (61, ' Female')
# (44, ' Female')
# (57, ' Female')
# (30, ' Female')
# (51, ' Female')
# (39, ' Female')
# (59, ' Female')
# (35, ' Female')
# (52, ' Female')
# (40, ' Female')
# (44, ' Male')
# (22, ' Male')
# (44, ' Male')
# (33, ' Female')
# (45, ' Female')
# (39, ' Female')
# (36, ' Male')
# (45, ' Female')
# (22, ' Female')
# (49, ' Female')
# (34, ' Female')
# (40, ' Female')
# (67, ' Female')
# (48, ' Female')
# (55, ' Female')
# (63, ' Female')
# (60, ' Female')
# (46, ' Female')
# (47, ' Male')
# (27, ' Male')
# (56, ' Female')
# (47, ' Female')
# (36, ' Female')
# (40, ' Female')
# (32, ' Male')
# (34, ' Female')
# (41, ' Male')
# (38, ' Female')
# (47, ' Female')
# (49, ' Female')
# (37, ' Female')
# (41, ' Female')
# (50, ' Female')
# (38, ' Female')
# (46, ' Male')
# (42, ' Female')
# (45, ' Female')
# (45, ' Female')
# (46, ' Male')
# (37, ' Female')
# (46, ' Female')
# (36, ' Female')
# (33, ' Male')
# (47, ' Female')
# (52, ' Female')
# (36, ' Male')
# (45, ' Male')
# (23, ' Male')
# (32, ' Male')
# (52, ' Male')
# (27, ' Female')
# (52, ' Female')
# (42, ' Male')
# (41, ' Female')
# (44, ' Male')
# (48, ' Female')
# (39, ' Male')
# (32, ' Male')
# (30, ' Male')
# (41, ' Female')
# (45, ' Female')
# (40, ' Male')
# (36, ' Male')
# (49, ' Female')
# (38, ' Male')
# (41, ' Male')
# (64, ' Female')
# (24, ' Female')
# (37, ' Male')
# (35, ' Male')
# (40, ' Female')
# (46, ' Female')
# (48, ' Male')
# (36, ' Male')
# (37, ' Male')
# (44, ' Male')
# (42, ' Male')
# (41, ' Female')
# (23, ' Female')
# (39, ' Female')
# (32, ' Male')
# (50, ' Male')
# (49, ' Female')
# (55, ' Female')
# (48, ' Female')
# (46, ' Female')
# (37, ' Female')
# (37, ' Female')
# (33, ' Female')
# (26, ' Female')
# (31, ' Female')
# (23, ' Female')
# (35, ' Female')
# (53, ' Male')
# (22, ' Male')
# (33, ' Female')
# (33, ' Male')
# (50, ' Male')
# (40, ' Male')
# (36, ' Female')
# (41, ' Female')
# (54, ' Female')
# (34, ' Male')
# (45, ' Female')
# (36, ' Male')
# (51, ' Male')
# (40, ' Female')
# (60, ' Female')
# (46, ' Female')
# (60, ' Female')
# (61, ' Male')
# (65, ' Female')
# (40, ' Male')
# (46, ' Female')
# (35, ' Female')
# (35, ' Female')
# (31, ' Male')
# (49, ' Female')
# (47, ' Female')
# (45, ' Female')
# (45, ' Female')
# (35, ' Female')
# (47, ' Male')
# (51, ' Female')
# (44, ' Female')
# (53, ' Male')
# (54, ' Male')
# (68, ' Female')
# (56, ' Female')
# (41, ' Female')
# (43, ' Female')
# (27, ' Female')
# (39, ' Male')
# (52, ' Male')
# (28, ' Female')
# (40, ' Female')
# (62, ' Female')
# (59, ' Male')
# (42, ' Female')
# (58, ' Male')
# (29, ' Male')
# (35, ' Female')
# (41, ' Male')
# (36, ' Female')
# (37, ' Male')
# (31, ' Male')
# (81, ' Female')
# (29, ' Female')
# (52, ' Male')
# (51, ' Female')
# (50, ' Female')
# (29, ' Male')
# (47, ' Female')
# (46, ' Female')
# (48, ' Female')
# (47, ' Male')
# (50, ' Female')
# (55, ' Female')
# (35, ' Female')
# (45, ' Female')
# (48, ' Female')
# (34, ' Female')
# (47, ' Female')
# (34, ' Female')
# (29, ' Female')
# (51, ' Female')
# (64, ' Male')
# (42, ' Female')
# (33, ' Male')
# (50, ' Male')
# (28, ' Male')
# (67, ' Male')
# (31, ' Male')
# (30, ' Male')
# (34, ' Female')
# (50, ' Female')
# (29, ' Male')
# (32, ' Male')
# (25, ' Female')
# (37, ' Female')
# (45, ' Male')
# (20, ' Female')
# (42, ' Female')
# (59, ' Female')
# (52, ' Male')
# (32, ' Female')
# (31, ' Male')
# (37, ' Male')
# (43, ' Male')
# (56, ' Male')
# (31, ' Female')
# (32, ' Female')
# (65, ' Female')
# (43, ' Female')
# (41, ' Male')
# (49, ' Female')
# (40, ' Female')
# (45, ' Female')
# (56, ' Female')
# (43, ' Female')
# (40, ' Male')
# (58, ' Female')
# (46, ' Female')
# (50, ' Male')
# (58, ' Male')
# (56, ' Female')
# (59, ' Female')
# (27, ' Female')
# (31, ' Male')
# (45, ' Female')
# (35, ' Male')
# (42, ' Female')
# (45, ' Female')
# (43, ' Female')
# (29, ' Female')
# (45, ' Male')
# (28, ' Male')
# (41, ' Female')
# (43, ' Female')
# (65, ' Female')
# (43, ' Male')
# (47, ' Female')
# (49, ' Female')
# (40, ' Male')
# (37, ' Female')
# (40, ' Male')
# (66, ' Male')
# (59, ' Male')
# (30, ' Female')
# (47, ' Female')
# (40, ' Male')
# (39, ' Female')
# (49, ' Female')
# (34, ' Female')
# (29, ' Male')
# (61, ' Female')
# (34, ' Male')
# (34, ' Male')
# (35, ' Male')
# (38, ' Male')
# (35, ' Male')
# (32, ' Male')
# (43, ' Male')
# (49, ' Female')
# (38, ' Female')
# (40, ' Female')
# (27, ' Female')
# (42, ' Female')
# (32, ' Male')
# (30, ' Male')
# (59, ' Female')
# (53, ' Female')
# (37, ' Male')
# (31, ' Female')
# (44, ' Female')
# (36, ' Male')
# (37, ' Female')
# (60, ' Male')
# (35, ' Female')
# (43, ' Female')
# (61, ' Female')
# (33, ' Female')
# (58, ' Female')
# (31, ' Male')
# (45, ' Male')
# (38, ' Male')
# (48, ' Female')
# (45, ' Female')
# (70, ' Male')
# (33, ' Female')
# (29, ' Female')
# (22, ' Female')
# (23, ' Female')
# (53, ' Male')
# (26, ' Female')
# (46, ' Male')
# (30, ' Male')
# (28, ' Male')
# (54, ' Female')
# (42, ' Male')
# (39, ' Female')
# (39, ' Female')
# (56, ' Female')
# (60, ' Female')
# (37, ' Female')
# (58, ' Female')
# (43, ' Female')
# (56, ' Male')
# (40, ' Male')
# (45, ' Male')
# (36, ' Female')
# (44, ' Male')
# (23, ' Female')
# (65, ' Female')
# (38, ' Female')
# (26, ' Female')
# (26, ' Male')
# (47, ' Male')
# (30, ' Male')
# (27, ' Male')
# (49, ' Female')
# (61, ' Male')
# (55, ' Female')
# (30, ' Female')
# (36, ' Male')
# (43, ' Male')
# (51, ' Male')
# (37, ' Male')
# (37, ' Female')
# (37, ' Male')
# (55, ' Female')
# (29, ' Female')
# (56, ' Male')
# (42, ' Male')
# (68, ' Female')
# (38, ' Male')
# (28, ' Female')
# (51, ' Male')
# (49, ' Male')
# (53, ' Male')
# (36, ' Female')
# (38, ' Female')
# (52, ' Male')
# (45, ' Female')
# (39, ' Female')
# (36, ' Female')
# (46, ' Male')
# (45, ' Female')
# (47, ' Female')
# (50, ' Male')
# (25, ' Male')
# (32, ' Male')
# (46, ' Female')
# (46, ' Female')
# (51, ' Female')
# (51, ' Male')
# (50, ' Female')
# (46, ' Male')
# (36, ' Male')
# (31, ' Male')
# (25, ' Male')
# (42, ' Male')
# (30, ' Male')
# (35, ' Female')
# (33, ' Male')
# (45, ' Female')
# (50, ' Female')
# (32, ' Male')
# (46, ' Female')
# (36, ' Female')
# (40, ' Female')
# (59, ' Male')
# (40, ' Male')
# (44, ' Male')
# (47, ' Female')
# (44, ' Male')
# (33, ' Female')
# (38, ' Female')
# (40, ' Male')
# (46, ' Female')
# (58, ' Male')
# (52, ' Female')
# (39, ' Female')
# (47, ' Female')
# (27, ' Male')
# (48, ' Male')
# (47, ' Female')
# (42, ' Male')
# (34, ' Female')
# (43, ' Female')
# (39, ' Female')
# (53, ' Female')
# (47, ' Female')
# (27, ' Male')
# (63, ' Female')
# (50, ' Male')
# (58, ' Male')
# (60, ' Male')
# (32, ' Female')
# (49, ' Male')
# (53, ' Female')
# (36, ' Male')
# (47, ' Male')
# (41, ' Male')
# (20, ' Female')
# (36, ' Male')
# (30, ' Female')
# (41, ' Male')
# (47, ' Female')
# (49, ' Female')
# (46, ' Male')
# (44, ' Female')
# (36, ' Female')
# (46, ' Female')
# (43, ' Female')
# (36, ' Female')
# (36, ' Female')
# (40, ' Female')
# (67, ' Female')
# (35, ' Male')
# (63, ' Female')
# (50, ' Male')
# (48, ' Male')
# (63, ' Male')
# (55, ' Female')
# (27, ' Male')
# (58, ' Female')
# (53, ' Female')
# (43, ' Female')
# (50, ' Male')
# (26, ' Male')
# (50, ' Male')
# (53, ' Female')
# (31, ' Female')
# (30, ' Female')
# (44, ' Male')
# (33, ' Female')
# (48, ' Female')
# (48, ' Male')
# (28, ' Female')
# (43, ' Female')
# (46, ' Female')
# (37, ' Male')
# (47, ' Male')
# (55, ' Male')
# (44, ' Female')
# (39, ' Female')
# (34, ' Female')
# (24, ' Female')
# (28, ' Male')
# (58, ' Male')
# (48, ' Male')
# (38, ' Female')
# (50, ' Female')
# (49, ' Female')
# (31, ' Female')
# (33, ' Male')
# (47, ' Male')
# (35, ' Male')
# (35, ' Male')
# (29, ' Female')
# (65, ' Male')
# (49, ' Male')
# (50, ' Female')
# (31, ' Female')
# (45, ' Male')
# (31, ' Male')
# (44, ' Female')
# (27, ' Female')
# (39, ' Female')
# (45, ' Female')
# (35, ' Male')
# (45, ' Male')
# (50, ' Female')
# (39, ' Female')
# (27, ' Female')
# (52, ' Female')
# (22, ' Male')
# (30, ' Female')
# (69, ' Female')
# (35, ' Female')
# (48, ' Male')
# (46, ' Female')
# (36, ' Female')
# (35, ' Male')
# (39, ' Male')
# (44, ' Male')
# (44, ' Female')
# (35, ' Male')
# (50, ' Female')
# (41, ' Male')
# (33, ' Male')
# (50, ' Male')
# (60, ' Female')
# (43, ' Male')
# (28, ' Male')
# (51, ' Female')
# (44, ' Male')
# (51, ' Male')
# (45, ' Female')
# (39, ' Female')
# (45, ' Female')
# (27, ' Male')
# (51, ' Male')
# (58, ' Male')
# (41, ' Female')
# (31, ' Female')
# (50, ' Female')
# (63, ' Male')
# (48, ' Male')
# (24, ' Male')
# (43, ' Male')
# (26, ' Female')
# (36, ' Female')
# (41, ' Male')
# (36, ' Female')
# (30, ' Male')
# (35, ' Male')
# (39, ' Female')
# (32, ' Female')
# (48, ' Male')
# (33, ' Female')
# (51, ' Male')
# (33, ' Female')
# (41, ' Male')
# (42, ' Male')
# (32, ' Female')
# (50, ' Male')
# (46, ' Female')
# (58, ' Male')
# (54, ' Female')
# (40, ' Male')
# (44, ' Female')
# (36, ' Male')
# (61, ' Female')
# (42, ' Female')
# (43, ' Female')
# (28, ' Female')
# (55, ' Female')
# (34, ' Male')
# (43, ' Female')
# (54, ' Female')
# (65, ' Male')
# (37, ' Male')
# (29, ' Male')
# (47, ' Female')
# (35, ' Female')
# (38, ' Female')
# (23, ' Male')
# (57, ' Female')
# (34, ' Male')
# (42, ' Female')
# (51, ' Male')
# (28, ' Female')
# (46, ' Female')
# (33, ' Female')
# (48, ' Male')
# (30, ' Male')
# (64, ' Female')
# (40, ' Female')
# (28, ' Male')
# (29, ' Female')
# (26, ' Female')
# (38, ' Female')
# (31, ' Male')
# (29, ' Male')
# (50, ' Female')
# (33, ' Male')
# (37, ' Female')
# (45, ' Male')
# (32, ' Male')
# (49, ' Male')
# (45, ' Male')
# (43, ' Female')
# (43, ' Female')
# (45, ' Male')
# (39, ' Female')
# (49, ' Female')
# (45, ' Female')
# (28, ' Female')
# (41, ' Male')
# (57, ' Male')
# (47, ' Male')
# (50, ' Male')
# (40, ' Male')
# (55, ' Female')
# (42, ' Female')
# (48, ' Female')
# (48, ' Female')
# (50, ' Female')
# (44, ' Male')
# (65, ' Female')
# (51, ' Female')
# (54, ' Female')
# (60, ' Male')
# (58, ' Male')
# (35, ' Female')
# (32, ' Female')
# (37, ' Male')
# (36, ' Female')
# (46, ' Female')
# (32, ' Female')
# (70, ' Male')
# (40, ' Male')
# (58, ' Male')
# (38, ' Female')
# (62, ' Male')
# (55, ' Female')
# (50, ' Female')
# (60, ' Male')
# (60, ' Female')
# (32, ' Female')
# (37, ' Male')
# (53, ' Male')
# (41, ' Male')
# (51, ' Female')
# (63, ' Female')
# (48, ' Female')
# (30, ' Female')
# (41, ' Male')
# (22, ' Female')
# (33, ' Female')
# (38, ' Female')
# (24, ' Female')
# (31, ' Female')
# (29, ' Male')
# (33, ' Female')
# (54, ' Male')
# (39, ' Male')
# (31, ' Female')
# (54, ' Male')
# (54, ' Female')
# (39, ' Male')
# (50, ' Male')
# (36, ' Female')
# (43, ' Female')
# (69, ' Male')
# (39, ' Male')
# (43, ' Female')
# (42, ' Female')
# (37, ' Female')
# (30, ' Male')
# (46, ' Male')
# (57, ' Male')
# (37, ' Male')
# (39, ' Female')
# (50, ' Male')
# (53, ' Male')
# (45, ' Female')
# (38, ' Male')
# (50, ' Female')
# (41, ' Female')
# (35, ' Female')
# (71, ' Female')
# (57, ' Female')
# (39, ' Male')
# (37, ' Female')
# (28, ' Male')
# (42, ' Male')
# (47, ' Male')
# (29, ' Female')
# (49, ' Male')
# (32, ' Female')
# (37, ' Female')
# (38, ' Male')
# (44, ' Male')
# (25, ' Female')
# (45, ' Female')
# (49, ' Male')
# (24, ' Female')
# (30, ' Female')
# (47, ' Female')
# (41, ' Female')
# (49, ' Female')
# (44, ' Female')
# (45, ' Female')
# (56, ' Male')
# (38, ' Female')
# (35, ' Female')
# (36, ' Female')
# (24, ' Male')
# (35, ' Female')
# (40, ' Female')
# (36, ' Male')
# (37, ' Female')
# (59, ' Male')
# (35, ' Male')
# (45, ' Female')
# (45, ' Female')
# (29, ' Female')
# (39, ' Female')
# (44, ' Female')
# (34, ' Male')
# (43, ' Female')
# (32, ' Male')
# (34, ' Female')
# (54, ' Male')
# (42, ' Female')
# (30, ' Female')
# (39, ' Female')
# (43, ' Female')
# (35, ' Male')
# (48, ' Male')
# (27, ' Female')
# (46, ' Female')
# (76, ' Female')
# (25, ' Female')
# (41, ' Male')
# (42, ' Female')
# (43, ' Male')
# (51, ' Female')
# (41, ' Female')
# (67, ' Female')
# (40, ' Female')
# (39, ' Female')
# (39, ' Male')
# (54, ' Female')
# (36, ' Male')
# (53, ' Female')
# (55, ' Female')
# (36, ' Male')
# (37, ' Female')
# (61, ' Female')
# (36, ' Female')
# (39, ' Female')
# (39, ' Female')
# (32, ' Female')
# (29, ' Female')
# (45, ' Female')
# (35, ' Female')
# (53, ' Male')
# (38, ' Female')
# (47, ' Female')
# (34, ' Female')
# (60, ' Female')
# (33, ' Male')
# (44, ' Male')
# (26, ' Female')
# (45, ' Male')
# (58, ' Female')
# (50, ' Female')
# (57, ' Female')
# (40, ' Male')
# (55, ' Female')
# (76, ' Female')
# (48, ' Female')
# (35, ' Male')
# (29, ' Female')
# (30, ' Female')
# (28, ' Female')
# (45, ' Female')
# (26, ' Female')
# (52, ' Male')
# (45, ' Female')
# (57, ' Female')
# (38, ' Female')
# (63, ' Female')
# (47, ' Male')
# (36, ' Male')
# (60, ' Female')
# (39, ' Female')
# (39, ' Female')
# (35, ' Female')
# (68, ' Male')
# (43, ' Female')
# (50, ' Female')
# (55, ' Female')
# (42, ' Female')
# (30, ' Female')
# (28, ' Female')
# (34, ' Male')
# (42, ' Female')
# (49, ' Male')
# (48, ' Female')
# (24, ' Male')
# (36, ' Female')
# (45, ' Female')
# (38, ' Female')
# (34, ' Female')
# (42, ' Female')
# (43, ' Female')
# (50, ' Female')
# (48, ' Male')
# (43, ' Female')
# (35, ' Female')
# (35, ' Male')
# (30, ' Female')
# (51, ' Male')
# (44, ' Female')
# (49, ' Male')
# (28, ' Female')
# (42, ' Female')
# (63, ' Male')
# (30, ' Male')
# (45, ' Female')
# (41, ' Male')
# (70, ' Female')
# (39, ' Female')
# (40, ' Male')
# (51, ' Female')
# (22, ' Female')
# (21, ' Female')
# (47, ' Female')
# (49, ' Male')
# (58, ' Female')
# (58, ' Female')
# (49, ' Female')
# (60, ' Female')
# (55, ' Male')
# (64, ' Male')
# (43, ' Male')
# (31, ' Female')
# (38, ' Male')
# (48, ' Male')
# (41, ' Female')
# (52, ' Female')
# (51, ' Female')
# (39, ' Male')
# (48, ' Female')
# (46, ' Female')
# (26, ' Female')
# (40, ' Male')
# (38, ' Male')
# (33, ' Female')
# (57, ' Male')
# (60, ' Female')
# (46, ' Male')
# (32, ' Female')
# (36, ' Female')
# (56, ' Male')
# (56, ' Female')
# (41, ' Male')
# (57, ' Male')
# (35, ' Female')
# (27, ' Male')
# (40, ' Female')
# (65, ' Female')
# (51, ' Female')
# (52, ' Male')
# (28, ' Female')
# (60, ' Female')
# (28, ' Male')
# (37, ' Female')
# (28, ' Female')
# (27, ' Female')
# (49, ' Female')
# (56, ' Male')
# (40, ' Male')
# (45, ' Female')
# (58, ' Female')
# (53, ' Female')
# (40, ' Male')
# (51, ' Female')
# (33, ' Male')
# (50, ' Male')
# (46, ' Female')
# (41, ' Female')
# (49, ' Female')
# (47, ' Female')
# (41, ' Female')
# (32, ' Female')
# (54, ' Male')
# (32, ' Female')
# (39, ' Female')
# (29, ' Female')
# (45, ' Female')
# (43, ' Female')
# (47, ' Female')
# (46, ' Female')
# (37, ' Female')
# (39, ' Female')
# (33, ' Male')
# (44, ' Female')
# (24, ' Female')
# (29, ' Female')
# (41, ' Male')
# (38, ' Male')
# (48, ' Female')
# (39, ' Female')
# (37, ' Male')
# (35, ' Female')
# (49, ' Male')
# (34, ' Female')
# (61, ' Female')
# (42, ' Female')
# (35, ' Male')
# (40, ' Male')
# (49, ' Male')
# (31, ' Male')
# (34, ' Female')
# (42, ' Male')
# (37, ' Female')
# (49, ' Female')
# (46, ' Female')
# (37, ' Male')
# (27, ' Female')
# (29, ' Female')
# (26, ' Female')
# (57, ' Male')
# (50, ' Female')
# (47, ' Male')
# (47, ' Female')
# (38, ' Male')
# (56, ' Male')
# (45, ' Male')
# (65, ' Female')
# (75, ' Female')
# (42, ' Female')
# (58, ' Male')
# (59, ' Female')
# (47, ' Male')
# (30, ' Male')
# (51, ' Female')
# (21, ' Male')
# (47, ' Male')
# (31, ' Female')
# (52, ' Female')
# (32, ' Male')
# (35, ' Male')
# (53, ' Female')
# (29, ' Male')
# (39, ' Female')
# (49, ' Male')
# (48, ' Female')
# (45, ' Male')
# (44, ' Female')
# (39, ' Male')
# (46, ' Female')
# (40, ' Female')
# (34, ' Female')
# (33, ' Male')
# (59, ' Female')
# (56, ' Female')
# (30, ' Male')
# (31, ' Female')
# (39, ' Female')
# (39, ' Male')
# (43, ' Female')
# (24, ' Female')
# (37, ' Female')
# (40, ' Female')
# (36, ' Female')
# (47, ' Female')
# (44, ' Female')
# (59, ' Male')
# (40, ' Female')
# (24, ' Female')
# (51, ' Female')
# (31, ' Female')
# (58, ' Male')
# (27, ' Female')
# (33, ' Female')
# (44, ' Male')
# (45, ' Female')
# (58, ' Male')
# (72, ' Female')
# (37, ' Male')
# (44, ' Female')
# (33, ' Female')
# (42, ' Female')
# (48, ' Female')
# (42, ' Female')
# (39, ' Female')
# (37, ' Male')
# (47, ' Female')
# (49, ' Female')
# (61, ' Male')
# (45, ' Male')
# (46, ' Male')
# (33, ' Female')
# (48, ' Male')
# (44, ' Male')
# (45, ' Female')
# (52, ' Male')
# (42, ' Male')
# (40, ' Female')
# (34, ' Female')
# (60, ' Female')
# (31, ' Female')
# (59, ' Female')
# (35, ' Male')
# (37, ' Male')
# (30, ' Female')
# (32, ' Male')
# (33, ' Male')
# (27, ' Female')
# (38, ' Female')
# (55, ' Female')
# (66, ' Female')
# (49, ' Female')
# (34, ' Male')
# (37, ' Female')
# (55, ' Female')
# (30, ' Male')
# (49, ' Male')
# (49, ' Male')
# (62, ' Female')
# (42, ' Female')
# (43, ' Female')
# (40, ' Male')
# (37, ' Male')
# (34, ' Female')
# (34, ' Male')
# (45, ' Female')
# (65, ' Male')
# (33, ' Female')
# (41, ' Female')
# (47, ' Female')
# (37, ' Male')
# (43, ' Male')
# (64, ' Female')
# (36, ' Female')
# (46, ' Female')
# (43, ' Male')
# (64, ' Male')
# (46, ' Female')
# (29, ' Female')
# (48, ' Female')
# (50, ' Female')
# (37, ' Female')
# (52, ' Male')
# (41, ' Male')
# (51, ' Male')
# (25, ' Female')
# (45, ' Female')
# (25, ' Female')
# (48, ' Female')
# (34, ' Female')
# (35, ' Female')
# (64, ' Male')
# (36, ' Male')
# (41, ' Male')
# (59, ' Male')
# (39, ' Female')
# (38, ' Female')
# (31, ' Male')
# (32, ' Male')
# (44, ' Female')
# (53, ' Female')
# (50, ' Female')
# (39, ' Female')
# (29, ' Female')
# (43, ' Female')
# (33, ' Female')
# (41, ' Male')
# (34, ' Female')
# (48, ' Female')
# (30, ' Female')
# (50, ' Female')
# (47, ' Female')
# (44, ' Male')
# (38, ' Female')
# (23, ' Female')
# (67, ' Female')
# (42, ' Female')
# (31, ' Male')
# (61, ' Female')
# (49, ' Male')
# (50, ' Female')
# (49, ' Male')
# (56, ' Female')
# (40, ' Female')
# (39, ' Female')
# (53, ' Female')
# (57, ' Female')
# (39, ' Female')
# (48, ' Male')
# (33, ' Male')
# (34, ' Male')
# (55, ' Female')
# (43, ' Female')
# (46, ' Female')
# (36, ' Male')
# (26, ' Female')
# (70, ' Female')
# (26, ' Male')
# (36, ' Male')
# (48, ' Male')
# (28, ' Female')
# (50, ' Female')
# (33, ' Female')
# (45, ' Female')
# (65, ' Male')
# (31, ' Female')
# (32, ' Male')
# (56, ' Female')
# (35, ' Female')
# (22, ' Male')
# (66, ' Female')
# (50, ' Female')
# (42, ' Female')
# (36, ' Male')
# (62, ' Female')
# (31, ' Male')
# (49, ' Female')
# (35, ' Female')
# (46, ' Female')
# (37, ' Male')
# (52, ' Female')
# (31, ' Female')
# (29, ' Female')
# (53, ' Female')
# (62, ' Male')
# (44, ' Male')
# (44, ' Male')
# (49, ' Male')
# (53, ' Male')
# (47, ' Female')
# (54, ' Male')
# (45, ' Female')
# (32, ' Male')
# (38, ' Male')
# (38, ' Male')
# (35, ' Male')
# (32, ' Male')
# (31, ' Female')
# (42, ' Female')
# (42, ' Male')
# (40, ' Male')
# (39, ' Male')
# (44, ' Male')
# (53, ' Female')
# (60, ' Female')
# (58, ' Female')
# (42, ' Female')
# (54, ' Female')
# (54, ' Female')
# (39, ' Male')
# (53, ' Female')
# (41, ' Male')
# (55, ' Male')
# (45, ' Female')
# (44, ' Male')
# (26, ' Male')
# (40, ' Male')
# (28, ' Female')
# (51, ' Female')
# (31, ' Female')
# (29, ' Female')
# (33, ' Male')
# (59, ' Female')
# (67, ' Male')
# (26, ' Male')
# (44, ' Male')
# (64, ' Female')
# (56, ' Male')
# (38, ' Female')
# (66, ' Male')
# (31, ' Male')
# (39, ' Female')
# (49, ' Male')
# (36, ' Female')
# (62, ' Female')
# (43, ' Female')
# (29, ' Female')
# (48, ' Male')
# (34, ' Female')
# (33, ' Female')
# (50, ' Female')
# (60, ' Male')
# (32, ' Female')
# (31, ' Female')
# (58, ' Female')
# (40, ' Male')
# (32, ' Female')
# (46, ' Female')
# (36, ' Female')
# (29, ' Female')
# (39, ' Male')
# (33, ' Male')
# (40, ' Male')
# (68, ' Female')
# (52, ' Male')
# (52, ' Male')
# (60, ' Male')
# (38, ' Female')
# (44, ' Female')
# (46, ' Male')
# (56, ' Male')
# (56, ' Male')
# (27, ' Male')
# (46, ' Female')
# (36, ' Male')
# (44, ' Male')
# (45, ' Female')
# (53, ' Male')
# (59, ' Male')
# (45, ' Female')
# (43, ' Female')
# (53, ' Male')
# (44, ' Male')
# (49, ' Female')
# (34, ' Male')
# (45, ' Male')
# (55, ' Male')
# (49, ' Female')
# (51, ' Female')
# (59, ' Male')
# (53, ' Male')
# (43, ' Female')
# (49, ' Male')
# (32, ' Male')
# (45, ' Male')
# (34, ' Male')
# (26, ' Male')
# (58, ' Male')
# (54, ' Female')
# (58, ' Female')
# (63, ' Male')
# (67, ' Female')
# (55, ' Female')
# (39, ' Female')
# (41, ' Male')
# (44, ' Female')
# (38, ' Female')
# (50, ' Female')
# (47, ' Female')
# (64, ' Male')
# (39, ' Female')
# (57, ' Male')
# (41, ' Male')
# (48, ' Female')
# (42, ' Male')
# (58, ' Female')
# (39, ' Female')
# (41, ' Male')
# (44, ' Female')
# (44, ' Male')
# (40, ' Male')
# (54, ' Male')
# (43, ' Female')
# (45, ' Female')
# (40, ' Male')
# (58, ' Male')
# (39, ' Male')
# (27, ' Male')
# (30, ' Female')
# (63, ' Male')
# (47, ' Male')
# (41, ' Female')
# (40, ' Female')
# (50, ' Female')
# (39, ' Female')
# (40, ' Male')
# (56, ' Female')
# (57, ' Female')
# (41, ' Male')
# (28, ' Male')
# (36, ' Male')
# (30, ' Male')
# (33, ' Male')
# (39, ' Male')
# (45, ' Female')
# (34, ' Male')
# (44, ' Male')
# (34, ' Male')
# (33, ' Female')
# (52, ' Female')
# (58, ' Female')
# (39, ' Female')
# (53, ' Male')
# (43, ' Male')
# (38, ' Female')
# (42, ' Female')
# (53, ' Male')
# (54, ' Male')
# (33, ' Male')
# (45, ' Female')
# (35, ' Female')
# (32, ' Female')
# (47, ' Female')
# (32, ' Female')
# (44, ' Female')
# (55, ' Female')
# (59, ' Female')
# (53, ' Female')
# (52, ' Female')
# (44, ' Female')
# (49, ' Female')
# (46, ' Female')
# (52, ' Female')
# (42, ' Female')
# (51, ' Female')
# (52, ' Female')
# (40, ' Female')
# (45, ' Male')
# (51, ' Female')
# (42, ' Female')
# (34, ' Male')
# (28, ' Female')
# (45, ' Female')
# (40, ' Male')
# (34, ' Male')
# (30, ' Female')
# (51, ' Male')
# (53, ' Male')
# (53, ' Female')
# (42, ' Male')
# (33, ' Female')
# (44, ' Female')
# (49, ' Female')
# (31, ' Female')
# (33, ' Male')
# (46, ' Female')
# (29, ' Male')
# (61, ' Male')
# (59, ' Male')
# (36, ' Male')
# (43, ' Female')
# (41, ' Male')
# (35, ' Female')
# (36, ' Female')
# (32, ' Female')
# (45, ' Female')
# (51, ' Female')
# (33, ' Male')
# (36, ' Female')
# (35, ' Female')
# (44, ' Male')
# (38, ' Female')
# (49, ' Female')
# (27, ' Female')
# (38, ' Female')
# (28, ' Female')
# (49, ' Male')
# (42, ' Male')
# (35, ' Female')
# (48, ' Male')
# (53, ' Female')
# (37, ' Male')
# (49, ' Female')
# (33, ' Male')
# (50, ' Male')
# (52, ' Male')
# (50, ' Female')
# (42, ' Male')
# (55, ' Female')
# (25, ' Female')
# (42, ' Male')
# (40, ' Male')
# (36, ' Male')
# (36, ' Male')
# (56, ' Female')
# (45, ' Male')
# (45, ' Female')
# (30, ' Female')
# (45, ' Male')
# (35, ' Female')
# (45, ' Female')
# (46, ' Female')
# (44, ' Female')
# (46, ' Female')
# (51, ' Male')
# (48, ' Female')
# (45, ' Female')
# (49, ' Female')
# (36, ' Female')
# (20, ' Female')
# (43, ' Male')
# (44, ' Female')
# (45, ' Male')
# (51, ' Male')
# (37, ' Female')
# (58, ' Female')
# (30, ' Male')
# (44, ' Female')
# (33, ' Female')
# (58, ' Male')
# (41, ' Male')
# (41, ' Male')
# (25, ' Female')
# (57, ' Female')
# (30, ' Female')
# (39, ' Male')
# (54, ' Male')
# (63, ' Female')
# (64, ' Male')
# (40, ' Female')
# (29, ' Male')
# (44, ' Female')
# (41, ' Female')
# (55, ' Female')
# (53, ' Female')
# (49, ' Male')
# (19, ' Female')
# (38, ' Female')
# (41, ' Female')
# (45, ' Female')
# (35, ' Male')
# (40, ' Female')
# (62, ' Female')
# (59, ' Female')
# (57, ' Female')
# (41, ' Male')
# (43, ' Male')
# (43, ' Male')
# (32, ' Male')
# (34, ' Female')
# (39, ' Female')
# (39, ' Male')
# (46, ' Female')
# (32, ' Female')
# (46, ' Male')
# (36, ' Male')
# (50, ' Female')
# (41, ' Male')
# (53, ' Female')
# (40, ' Male')
# (38, ' Female')
# (43, ' Male')
# (47, ' Male')
# (46, ' Female')
# (34, ' Female')
# (46, ' Female')
# (44, ' Female')
# (45, ' Female')
# (49, ' Female')
# (49, ' Female')
# (42, ' Female')
# (36, ' Female')
# (55, ' Female')
# (55, ' Female')
# (51, ' Male')
# (35, ' Male')
# (44, ' Female')
# (43, ' Male')
# (51, ' Female')
# (40, ' Male')
# (43, ' Female')
# (59, ' Female')
# (46, ' Female')
# (31, ' Female')
# (36, ' Female')
# (38, ' Male')
# (50, ' Female')
# (49, ' Female')
# (43, ' Female')
# (35, ' Male')
# (36, ' Female')
# (42, ' Male')
# (48, ' Female')
# (23, ' Male')
# (26, ' Female')
# (36, ' Male')
# (42, ' Female')
# (60, ' Female')
# (49, ' Female')
# (38, ' Female')
# (58, ' Female')
# (55, ' Female')
# (39, ' Female')
# (38, ' Female')
# (25, ' Female')
# (39, ' Female')
# (40, ' Female')
# (41, ' Male')
# (49, ' Female')
# (55, ' Female')
# (52, ' Male')
# (58, ' Female')
# (41, ' Male')
# (32, ' Male')
# (48, ' Male')
# (48, ' Female')
# (35, ' Male')
# (49, ' Male')
# (56, ' Female')
# (26, ' Female')
# (36, ' Female')
# (41, ' Female')
# (50, ' Female')
# (34, ' Male')
# (37, ' Male')
# (36, ' Female')
# (33, ' Male')
# (54, ' Female')
# (51, ' Male')
# (44, ' Female')
# (45, ' Female')
# (44, ' Female')
# (31, ' Female')
# (40, ' Female')
# (42, ' Male')
# (41, ' Female')
# (41, ' Male')
# (51, ' Female')
# (36, ' Male')
# (40, ' Female')
# (46, ' Female')
# (44, ' Male')
# (36, ' Male')
# (44, ' Female')
# (52, ' Female')
# (20, ' Female')
# (36, ' Female')
# (30, ' Male')
# (51, ' Male')
# (57, ' Female')
# (35, ' Female')
# (59, ' Female')
# (36, ' Female')
# (67, ' Male')
# (36, ' Male')
# (32, ' Female')
# (48, ' Female')
# (45, ' Female')
# (37, ' Female')
# (29, ' Male')
# (42, ' Female')
# (57, ' Female')
# (50, ' Male')
# (37, ' Male')
# (55, ' Male')
# (39, ' Female')
# (27, ' Female')
# (43, ' Male')
# (28, ' Female')
# (26, ' Male')
# (39, ' Female')
# (43, ' Male')
# (43, ' Female')
# (40, ' Female')
# (50, ' Male')
# (74, ' Male')
# (32, ' Female')
# (29, ' Male')
# (39, ' Male')
# (40, ' Female')
# (45, ' Male')
# (47, ' Female')
# (32, ' Female')
# (34, ' Male')
# (58, ' Female')
# (23, ' Male')
# (29, ' Female')
# (61, ' Male')
# (51, ' Female')
# (50, ' Female')
# (65, ' Female')
# (64, ' Female')
# (32, ' Female')
# (34, ' Female')
# (37, ' Male')
# (60, ' Female')
# (47, ' Male')
# (30, ' Female')
# (38, ' Male')
# (30, ' Male')
# (49, ' Female')
# (52, ' Male')
# (36, ' Female')
# (37, ' Female')
# (48, ' Male')
# (58, ' Male')
# (33, ' Female')
# (31, ' Male')
# (35, ' Male')
# (41, ' Female')
# (36, ' Female')
# (34, ' Male')
# (64, ' Male')
# (47, ' Male')
# (44, ' Male')
# (32, ' Female')
# (58, ' Female')
# (36, ' Female')
# (46, ' Female')
# (43, ' Female')
# (35, ' Female')
# (46, ' Female')
# (41, ' Female')
# (52, ' Female')
# (41, ' Male')
# (44, ' Female')
# (46, ' Male')
# (45, ' Female')
# (26, ' Female')
# (47, ' Female')
# (44, ' Male')
# (25, ' Female')
# (36, ' Male')
# (47, ' Male')
# (25, ' Female')
# (53, ' Female')
# (41, ' Male')
# (35, ' Female')
# (46, ' Female')
# (48, ' Female')
# (48, ' Male')
# (55, ' Female')
# (50, ' Female')
# (46, ' Female')
# (45, ' Female')
# (44, ' Male')
# (44, ' Female')
# (52, ' Female')
# (31, ' Female')
# (45, ' Female')
# (37, ' Female')
# (44, ' Male')
# (45, ' Female')
# (40, ' Female')
# (24, ' Female')
# (55, ' Female')
# (46, ' Female')
# (58, ' Male')
# (35, ' Male')
# (49, ' Female')
# (44, ' Female')
# (38, ' Female')
# (42, ' Female')
# (43, ' Male')
# (53, ' Female')
# (58, ' Female')
# (41, ' Female')
# (44, ' Female')
# (40, ' Male')
# (51, ' Female')
# (73, ' Female')
# (44, ' Female')
# (42, ' Female')
# (42, ' Male')
# (59, ' Female')
# (47, ' Female')
# (36, ' Male')
# (53, ' Female')
# (37, ' Female')
# (41, ' Male')
# (40, ' Female')
# (52, ' Female')
# (83, ' Male')
# (35, ' Female')
# (45, ' Male')
# (90, ' Female')
# (57, ' Female')
# (35, ' Male')
# (40, ' Female')
# (46, ' Male')
# (45, ' Female')
# (50, ' Female')
# (56, ' Female')
# (36, ' Female')
# (45, ' Female')
# (53, ' Female')
# (32, ' Male')
# (49, ' Female')
# (41, ' Female')
# (32, ' Female')
# (33, ' Female')
# (30, ' Female')
# (64, ' Female')
# (49, ' Male')
# (35, ' Male')
# (68, ' Female')
# (60, ' Male')
# (48, ' Male')
# (62, ' Male')
# (60, ' Female')
# (39, ' Female')
# (45, ' Female')
# (48, ' Male')
# (44, ' Male')
# (37, ' Female')
# (46, ' Female')
# (39, ' Male')
# (30, ' Female')
# (43, ' Female')
# (26, ' Female')
# (48, ' Male')
# (41, ' Female')
# (49, ' Male')
# (36, ' Male')
# (38, ' Female')
# (43, ' Female')
# (63, ' Female')
# (41, ' Female')
# (36, ' Male')
# (32, ' Female')
# (50, ' Male')
# (37, ' Male')
# (54, ' Female')
# (51, ' Female')
# (38, ' Female')
# (43, ' Female')
# (28, ' Male')
# (43, ' Female')
# (49, ' Female')
# (36, ' Male')
# (44, ' Male')
# (40, ' Female')
# (55, ' Male')
# (51, ' Female')
# (44, ' Male')
# (40, ' Male')
# (43, ' Female')
# (48, ' Female')
# (36, ' Female')
# (30, ' Female')
# (52, ' Male')
# (46, ' Female')
# (41, ' Female')
# (43, ' Female')
# (30, ' Female')
# (43, ' Female')
# (54, ' Male')
# (60, ' Female')
# (52, ' Female')
# (48, ' Male')
# (23, ' Female')
# (40, ' Female')
# (35, ' Male')
# (47, ' Male')
# (50, ' Male')
# (37, ' Female')
# (42, ' Male')
# (61, ' Male')
# (45, ' Male')
# (60, ' Female')
# (37, ' Male')
# (47, ' Male')
# (43, ' Female')
# (58, ' Female')
# (39, ' Female')
# (58, ' Female')
# (57, ' Female')
# (33, ' Male')
# (32, ' Male')
# (46, ' Male')
# (31, ' Male')
# (46, ' Female')
# (70, ' Male')
# (41, ' Female')
# (36, ' Male')
# (35, ' Female')
# (55, ' Male')
# (39, ' Male')
# (47, ' Female')
# (50, ' Male')
# (67, ' Female')
# (34, ' Female')
# (55, ' Male')
# (23, ' Female')
# (36, ' Female')
# (43, ' Female')
# (40, ' Female')
# (42, ' Female')
# (54, ' Male')
# (35, ' Female')
# (42, ' Female')
# (46, ' Male')
# (43, ' Female')
# (39, ' Female')
# (52, ' Male')
# (43, ' Male')
# (52, ' Female')
# (44, ' Male')
# (37, ' Male')
# (36, ' Male')
# (26, ' Female')
# (38, ' Female')
# (41, ' Female')
# (23, ' Female')
# (36, ' Male')
# (46, ' Male')
# (54, ' Male')
# (37, ' Female')
# (54, ' Female')
# (25, ' Female')
# (36, ' Female')
# (40, ' Female')
# (53, ' Male')
# (45, ' Male')
# (24, ' Male')
# (37, ' Female')
# (49, ' Female')
# (40, ' Female')
# (54, ' Male')
# (40, ' Female')
# (43, ' Female')
# (41, ' Female')
# (39, ' Female')
# (42, ' Female')
# (26, ' Male')
# (43, ' Female')
# (39, ' Male')
# (44, ' Female')
# (46, ' Female')
# (40, ' Female')
# (47, ' Female')
# (41, ' Female')
# (65, ' Male')
# (55, ' Male')
# (66, ' Female')
# (54, ' Male')
# (27, ' Female')
# (50, ' Female')
# (51, ' Female')
# (41, ' Female')
# (40, ' Male')
# (42, ' Female')
# (38, ' Male')
# (41, ' Female')
# (30, ' Female')
# (49, ' Female')
# (70, ' Male')
# (41, ' Female')
# (42, ' Male')
# (28, ' Male')
# (46, ' Male')
# (44, ' Male')
# (32, ' Female')
# (47, ' Female')
# (55, ' Female')
# (30, ' Female')
# (43, ' Male')
# (46, ' Male')
# (52, ' Female')
# (49, ' Female')
# (25, ' Male')
# (43, ' Male')
# (48, ' Female')
# (43, ' Female')
# (39, ' Female')
# (54, ' Male')
# (63, ' Male')
# (47, ' Female')
# (35, ' Male')
# (54, ' Female')
# (45, ' Male')
# (46, ' Male')
# (23, ' Male')
# (45, ' Female')
# (33, ' Female')
# (51, ' Female')
# (41, ' Female')
# (44, ' Female')
# (36, ' Female')
# (27, ' Male')
# (33, ' Female')
# (57, ' Female')
# (40, ' Female')
# (33, ' Male')
# (46, ' Male')
# (40, ' Female')
# (41, ' Male')
# (55, ' Male')
# (37, ' Male')
# (49, ' Male')
# (37, ' Female')
# (43, ' Male')
# (25, ' Male')
# (45, ' Female')
# (37, ' Female')
# (51, ' Male')
# (52, ' Female')
# (36, ' Male')
# (42, ' Male')
# (61, ' Female')
# (37, ' Male')
# (51, ' Female')
# (30, ' Male')
# (26, ' Female')
# (35, ' Female')
# (52, ' Male')
# (38, ' Female')
# (57, ' Male')
# (27, ' Female')
# (47, ' Male')
# (41, ' Female')
# (52, ' Female')
# (60, ' Female')
# (61, ' Female')
# (26, ' Male')
# (32, ' Male')
# (63, ' Male')
# (31, ' Female')
# (55, ' Female')
# (41, ' Female')
# (38, ' Female')
# (36, ' Female')
# (40, ' Female')
# (36, ' Female')
# (33, ' Male')
# (38, ' Male')
# (53, ' Male')
# (42, ' Male')
# (61, ' Female')
# (44, ' Female')
# (46, ' Female')
# (49, ' Male')
# (40, ' Female')
# (43, ' Male')
# (44, ' Male')
# (52, ' Male')
# (47, ' Female')
# (37, ' Female')
# (61, ' Male')
# (32, ' Male')
# (37, ' Male')
# (38, ' Male')
# (33, ' Female')
# (57, ' Female')
# (35, ' Male')
# (39, ' Female')
# (61, ' Female')
# (47, ' Female')
# (43, ' Male')
# (40, ' Female')
# (48, ' Male')
# (49, ' Male')
# (50, ' Female')
# (62, ' Female')
# (35, ' Male')
# (29, ' Female')
# (62, ' Male')
# (51, ' Male')
# (55, ' Male')
# (31, ' Male')
# (32, ' Male')
# (31, ' Male')
# (47, ' Female')
# (42, ' Female')
# (38, ' Male')
# (47, ' Female')
# (32, ' Female')
# (39, ' Female')
# (33, ' Male')
# (28, ' Male')
# (47, ' Male')
# (33, ' Female')
# (61, ' Male')
# (37, ' Female')
# (25, ' Female')
# (37, ' Female')
# (40, ' Male')
# (32, ' Male')
# (39, ' Female')
# (34, ' Male')
# (31, ' Female')
# (41, ' Male')
# (36, ' Male')
# (55, ' Female')
# (41, ' Male')
# (35, ' Female')
# (25, ' Female')
# (35, ' Female')
# (35, ' Female')
# (55, ' Female')
# (46, ' Female')
# (47, ' Female')
# (46, ' Female')
# (57, ' Female')
# (37, ' Male')
# (38, ' Male')
# (41, ' Male')
# (52, ' Female')
# (48, ' Male')
# (48, ' Male')
# (56, ' Female')
# (47, ' Female')
# (37, ' Female')
# (30, ' Male')
# (38, ' Female')
# (45, ' Male')
# (49, ' Female')
# (35, ' Female')
# (50, ' Male')
# (41, ' Male')
# (60, ' Male')
# (67, ' Female')
# (62, ' Female')
# (37, ' Female')
# (34, ' Female')
# (44, ' Male')
# (38, ' Female')
# (45, ' Male')
# (41, ' Male')
# (50, ' Female')
# (53, ' Female')
# (34, ' Male')
# (36, ' Male')
# (33, ' Male')
# (45, ' Male')
# (35, ' Female')
# (45, ' Male')
# (49, ' Female')
# (28, ' Female')
# (37, ' Male')
# (65, ' Female')
# (42, ' Female')
# (42, ' Female')
# (39, ' Female')
# (36, ' Female')
# (57, ' Female')
# (42, ' Female')
# (42, ' Male')
# (40, ' Male')
# (67, ' Male')
# (65, ' Female')
# (50, ' Female')
# (38, ' Female')
# (34, ' Male')
# (37, ' Male')
# (28, ' Female')
# (62, ' Female')
# (48, ' Female')
# (42, ' Male')
# (30, ' Female')
# (48, ' Male')
# (70, ' Female')
# (37, ' Male')
# (34, ' Female')
# (32, ' Female')
# (32, ' Female')
# (58, ' Male')
# (52, ' Female')
# (41, ' Female')
# (59, ' Male')
# (30, ' Female')
# (47, ' Female')
# (44, ' Female')
# (26, ' Female')
# (52, ' Male')
# (46, ' Female')
# (55, ' Male')
# (33, ' Female')
# (43, ' Female')
# (39, ' Female')
# (29, ' Male')
# (49, ' Male')
# (56, ' Female')
# (57, ' Male')
# (29, ' Female')
# (28, ' Female')
# (29, ' Female')
# (42, ' Male')
# (56, ' Male')
# (53, ' Female')
# (48, ' Male')
# (38, ' Female')
# (55, ' Male')
# (52, ' Female')
# (45, ' Male')
# (46, ' Female')
# (45, ' Male')
# (50, ' Female')
# (62, ' Female')
# (67, ' Female')
# (45, ' Male')
# (69, ' Female')
# (38, ' Female')
# (39, ' Male')
# (27, ' Female')
# (33, ' Female')
# (56, ' Female')
# (44, ' Female')
# (46, ' Female')
# (46, ' Female')
# (58, ' Male')
# (49, ' Male')
# (45, ' Male')
# (34, ' Male')
# (40, ' Female')
# (45, ' Male')
# (32, ' Female')
# (48, ' Male')
# (57, ' Female')
# (40, ' Female')
# (37, ' Male')
# (39, ' Male')
# (41, ' Male')
# (49, ' Male')
# (37, ' Male')
# (51, ' Female')
# (39, ' Female')
# (42, ' Female')
# (37, ' Male')
# (47, ' Female')
# (53, ' Male')
# (42, ' Female')
# (53, ' Male')
# (58, ' Male')
# (45, ' Female')
# (39, ' Female')
# (50, ' Male')
# (51, ' Female')
# (32, ' Female')
# (56, ' Male')
# (29, ' Male')
# (47, ' Female')
# (50, ' Male')
# (53, ' Male')
# (29, ' Female')
# (36, ' Male')
# (48, ' Female')
# (51, ' Female')
# (39, ' Male')
# (53, ' Male')
# (49, ' Female')
# (43, ' Female')
# (53, ' Female')
# (39, ' Female')
# (45, ' Male')
# (33, ' Female')
# (31, ' Female')
# (53, ' Male')
# (41, ' Female')
# (40, ' Female')
# (27, ' Female')
# (30, ' Female')
# (39, ' Male')
# (48, ' Female')
# (34, ' Male')
# (33, ' Male')
# (44, ' Female')
# (30, ' Female')
# (46, ' Female')
# (35, ' Female')
# (61, ' Female')
# (57, ' Male')
# (28, ' Female')
# (60, ' Male')
# (29, ' Male')
# (50, ' Female')
# (45, ' Female')
# (88, ' Female')
# (52, ' Male')
# (51, ' Female')
# (25, ' Female')
# (37, ' Female')
# (39, ' Female')
# (40, ' Female')
# (38, ' Male')
# (46, ' Male')
# (52, ' Female')
# (31, ' Female')
# (36, ' Female')
# (33, ' Male')
# (40, ' Male')
# (56, ' Female')
# (68, ' Female')
# (45, ' Female')
# (37, ' Male')
# (32, ' Female')
# (34, ' Female')
# (47, ' Female')
# (56, ' Female')
# (46, ' Female')
# (34, ' Male')
# (20, ' Female')
# (68, ' Male')
# (48, ' Female')
# (47, ' Female')
# (46, ' Male')
# (43, ' Male')
# (40, ' Male')
# (27, ' Female')
# (28, ' Male')
# (46, ' Male')
# (44, ' Male')
# (65, ' Female')
# (41, ' Male')
# (33, ' Female')
# (59, ' Female')
# (40, ' Female')
# (35, ' Female')
# (50, ' Male')
# (40, ' Female')
# (30, ' Female')
# (39, ' Female')
# (42, ' Male')
# (51, ' Female')
# (47, ' Female')
# (49, ' Male')
# (72, ' Male')
# (47, ' Female')
# (39, ' Female')
# (36, ' Female')
# (23, ' Female')
# (25, ' Male')
# (34, ' Female')
# (35, ' Female')
# (29, ' Female')
# (44, ' Male')
# (50, ' Female')
# (38, ' Female')
# (43, ' Male')
# (33, ' Female')
# (39, ' Male')
# (45, ' Male')
# (29, ' Male')
# (32, ' Female')
# (56, ' Female')
# (35, ' Male')
# (45, ' Male')
# (46, ' Male')
# (30, ' Male')
# (41, ' Female')
# (56, ' Female')
# (45, ' Female')
# (41, ' Female')
# (54, ' Female')
# (40, ' Male')
# (59, ' Male')
# (47, ' Female')
# (39, ' Male')
# (45, ' Male')
# (40, ' Female')
# (29, ' Male')
# (47, ' Male')
# (41, ' Male')
# (71, ' Female')
# (52, ' Female')
# (54, ' Male')
# (54, ' Female')
# (31, ' Female')
# (52, ' Female')
# (53, ' Male')
# (55, ' Female')
# (47, ' Female')
# (56, ' Female')
# (32, ' Female')
# (41, ' Female')
# (42, ' Female')
# (46, ' Female')
# (34, ' Male')
# (27, ' Female')
# (48, ' Male')
# (37, ' Female')
# (35, ' Female')
# (58, ' Female')
# (25, ' Female')
# (38, ' Female')
# (63, ' Female')
# (39, ' Female')
# (50, ' Male')
# (44, ' Female')
# (62, ' Female')
# (67, ' Female')
# (43, ' Female')
# (72, ' Male')
# (48, ' Female')
# (39, ' Female')
# (67, ' Female')
# (47, ' Female')
# (48, ' Male')
# (31, ' Female')
# (29, ' Female')
# (34, ' Female')
# (40, ' Female')
# (35, ' Male')
# (44, ' Female')
# (32, ' Male')
# (38, ' Female')
# (42, ' Female')
# (37, ' Female')
# (51, ' Female')
# (47, ' Female')
# (42, ' Male')
# (40, ' Female')
# (43, ' Female')
# (46, ' Male')
# (41, ' Female')
# (42, ' Female')
# (38, ' Male')
# (47, ' Female')
# (46, ' Female')
# (39, ' Female')
# (62, ' Male')
# (41, ' Female')
# (49, ' Male')
# (40, ' Male')
# (59, ' Male')
# (51, ' Female')
# (62, ' Male')
# (49, ' Female')
# (33, ' Female')
# (42, ' Male')
# (34, ' Female')
# (40, ' Female')
# (45, ' Female')
# (41, ' Male')
# (41, ' Female')
# (46, ' Male')
# (62, ' Male')
# (34, ' Male')
# (58, ' Female')
# (32, ' Male')
# (49, ' Female')
# (29, ' Male')
# (37, ' Female')
# (36, ' Female')
# (58, ' Female')
# (39, ' Female')
# (34, ' Female')
# (39, ' Female')
# (58, ' Female')
# (37, ' Female')
# (33, ' Female')
# ...
# (31, ' Male')
# (48, ' Female')
# (32, ' Male')
# (47, ' Male')
# (41, ' Male')
# (41, ' Male')
# (38, ' Male')
# (42, ' Female')
# (40, ' Male')
# (45, ' Female')
# (57, ' Female')
# (28, ' Female')
# (43, ' Female')
# (49, ' Female')
# (30, ' Female')
# (48, ' Female')
# (55, ' Male')
# (47, ' Female')
# (33, ' Female')
# (52, ' Male')
# (26, ' Female')
# (50, ' Female')
# (35, ' Male')
# (41, ' Female')
# (39, ' Male')
# (30, ' Male')
# (45, ' Female')
# (37, ' Female')
# (48, ' Female')
# (50, ' Female')
# (50, ' Male')
# (46, ' Female')
# (37, ' Female')
# (53, ' Female')
# (46, ' Male')
# (56, ' Female')
# (52, ' Female')
# (47, ' Female')
# (40, ' Female')
# (56, ' Male')
# (24, ' Female')
# (34, ' Male')
# (24, ' Female')
# (31, ' Female')
# (27, ' Male')
# (36, ' Female')
# (29, ' Male')
# (42, ' Female')
# (44, ' Female')
# (36, ' Female')
# (52, ' Male')
# (25, ' Male')
# (49, ' Female')
# (25, ' Female')
# (28, ' Female')
# (53, ' Female')
# (34, ' Female')
# (47, ' Female')
# (51, ' Female')
# (32, ' Male')
# (59, ' Female')
# (54, ' Male')
# (49, ' Female')
# (46, ' Male')
# (41, ' Female')
# (32, ' Male')
# (44, ' Male')
# (39, ' Female')
# (31, ' Male')
# (47, ' Female')
# (26, ' Male')
# (48, ' Male')
# (46, ' Male')
# (69, ' Female')
# (39, ' Female')
# (50, ' Female')
# (45, ' Male')
# (54, ' Female')
# (58, ' Female')
# (56, ' Female')
# (39, ' Female')
# (48, ' Female')
# (52, ' Male')
# (36, ' Male')
# (55, ' Male')
# (44, ' Female')
# (35, ' Male')
# (34, ' Female')
# (57, ' Female')
# (54, ' Male')
# (28, ' Female')
# (33, ' Female')
# (46, ' Male')
# (44, ' Female')
# (30, ' Female')
# (66, ' Female')
# (33, ' Female')
# (47, ' Female')
# (26, ' Male')
# (39, ' Female')
# (74, ' Female')
# (35, ' Male')
# (35, ' Male')
# (46, ' Female')
# (50, ' Female')
# (57, ' Male')
# (56, ' Female')
# (36, ' Male')
# (35, ' Female')
# (49, ' Female')
# (41, ' Female')
# (32, ' Male')
# (48, ' Male')
# (39, ' Male')
# (55, ' Male')
# (59, ' Female')
# (51, ' Female')
# (47, ' Female')
# (42, ' Male')
# (39, ' Female')
# (32, ' Female')
# (61, ' Female')
# (43, ' Female')
# (37, ' Male')
# (36, ' Male')
# (39, ' Male')
# (46, ' Male')
# (53, ' Female')
# (51, ' Male')
# (40, ' Male')
# (61, ' Female')
# (41, ' Female')
# (39, ' Male')
# (42, ' Female')
# (42, ' Female')
# (43, ' Male')
# (40, ' Male')
# (56, ' Female')
# (32, ' Female')
# (24, ' Male')
# (46, ' Male')
# (45, ' Male')
# (47, ' Female')
# (21, ' Male')
# (57, ' Female')
# (49, ' Female')
# (48, ' Female')
# (63, ' Female')
# (41, ' Female')
# (47, ' Female')
# (36, ' Male')
# (39, ' Male')
# (54, ' Female')
# (43, ' Female')
# (52, ' Female')
# (44, ' Female')
# (45, ' Male')
# (34, ' Male')
# (40, ' Female')
# (59, ' Male')
# (32, ' Male')
# (58, ' Female')
# (32, ' Male')
# (28, ' Male')
# (30, ' Female')
# (48, ' Male')
# (37, ' Female')
# (69, ' Male')
# (40, ' Male')
# (43, ' Male')
# (33, ' Male')
# (45, ' Female')
# (49, ' Female')
# (42, ' Male')
# (59, ' Female')
# (51, ' Female')
# (28, ' Male')
# (42, ' Female')
# (41, ' Female')
# (44, ' Male')
# (56, ' Female')
# (32, ' Female')
# (33, ' Female')
# (39, ' Male')
# (47, ' Male')
# (53, ' Female')
# (27, ' Female')
# (49, ' Female')
# (31, ' Female')
# (53, ' Female')
# (32, ' Male')
# (62, ' Female')
# (51, ' Female')
# (35, ' Female')
# (31, ' Male')
# (41, ' Female')
# (53, ' Male')
# (36, ' Female')
# (48, ' Male')
# (30, ' Female')
# (29, ' Male')
# (62, ' Male')
# (37, ' Male')
# (46, ' Female')
# (57, ' Female')
# (56, ' Male')
# (45, ' Female')
# (40, ' Female')
# (53, ' Male')
# (62, ' Male')
# (37, ' Male')
# (45, ' Male')
# (31, ' Female')
# (34, ' Female')
# (42, ' Male')
# (49, ' Female')
# (53, ' Female')
# (37, ' Male')
# (30, ' Female')
# (57, ' Female')
# (49, ' Female')
# (67, ' Male')
# (35, ' Male')
# (66, ' Female')
# (37, ' Male')
# (58, ' Female')
# (50, ' Female')
# (38, ' Male')
# (43, ' Male')
# (42, ' Female')
# (35, ' Male')
# (43, ' Female')
# (55, ' Female')
# (39, ' Male')
# (32, ' Male')
# (51, ' Male')
# (35, ' Female')
# (42, ' Female')
# (32, ' Male')
# (31, ' Female')
# (59, ' Male')
# (62, ' Female')
# (44, ' Male')
# (46, ' Male')
# (44, ' Male')
# (51, ' Female')
# (38, ' Female')
# (42, ' Male')
# (51, ' Female')
# (27, ' Male')
# (39, ' Female')
# (32, ' Female')
# (29, ' Male')
# (44, ' Female')
# (49, ' Female')
# (37, ' Female')
# (29, ' Female')
# (50, ' Male')
# (40, ' Female')
# (23, ' Female')
# (55, ' Female')
# (38, ' Male')
# (53, ' Female')
# (46, ' Female')
# (28, ' Male')
# (35, ' Female')
# (36, ' Female')
# (36, ' Male')
# (43, ' Female')
# (23, ' Female')
# (51, ' Male')
# (31, ' Male')
# (34, ' Male')
# (51, ' Female')
# (42, ' Female')
# (33, ' Female')
# (46, ' Female')
# (60, ' Male')
# (68, ' Female')
# (38, ' Female')
# (28, ' Male')
# (36, ' Male')
# (59, ' Male')
# (49, ' Female')
# (49, ' Female')
# (50, ' Male')
# (45, ' Female')
# (34, ' Female')
# (37, ' Female')
# (35, ' Female')
# (44, ' Male')
# (38, ' Female')
# (62, ' Female')
# (43, ' Female')
# (58, ' Female')
# (43, ' Male')
# (31, ' Female')
# (38, ' Male')
# (39, ' Female')
# (38, ' Female')
# (49, ' Female')
# (22, ' Female')
# (60, ' Female')
# (38, ' Male')
# (46, ' Female')
# (42, ' Female')
# (43, ' Female')
# (53, ' Female')
# (53, ' Male')
# (42, ' Male')
# (55, ' Female')
# (54, ' Female')
# (45, ' Male')
# (36, ' Female')
# (41, ' Female')
# (32, ' Female')
# (33, ' Female')
# (56, ' Male')
# (65, ' Female')
# (55, ' Male')
# (58, ' Male')
# (47, ' Female')
# (43, ' Female')
# (46, ' Female')
# (31, ' Male')
# (44, ' Male')
# (30, ' Male')
# (35, ' Male')
# (54, ' Male')
# (42, ' Male')
# (33, ' Female')
# (39, ' Male')
# (58, ' Female')
# (35, ' Male')
# (48, ' Female')
# (62, ' Female')
# (35, ' Female')
# (34, ' Male')
# (44, ' Male')
# (46, ' Male')
# (32, ' Male')
# (39, ' Male')
# (38, ' Male')
# (28, ' Male')
# (34, ' Male')
# (45, ' Male')
# (61, ' Female')
# (33, ' Male')
# (44, ' Female')
# (31, ' Female')
# (40, ' Female')
# (48, ' Female')
# (34, ' Male')
# (51, ' Female')
# (60, ' Male')
# (45, ' Female')
# (32, ' Female')
# (40, ' Female')
# (51, ' Male')
# (61, ' Female')
# (60, ' Male')
# (42, ' Female')
# (45, ' Male')
# (38, ' Female')
# (38, ' Male')
# (55, ' Female')
# (27, ' Female')
# (35, ' Female')
# (56, ' Female')
# (50, ' Female')
# (41, ' Female')
# (47, ' Female')
# (40, ' Female')
# (61, ' Female')
# (39, ' Male')
# (45, ' Female')
# (33, ' Female')
# (39, ' Male')
# (62, ' Female')
# (45, ' Male')
# (32, ' Female')
# (52, ' Male')
# (34, ' Male')
# (26, ' Female')
# (43, ' Female')
# (49, ' Male')
# (57, ' Female')
# (44, ' Male')
# (46, ' Female')
# (43, ' Female')
# (30, ' Female')
# (36, ' Female')
# (34, ' Male')
# (55, ' Male')
# (42, ' Female')
# (31, ' Male')
# (40, ' Male')
# (46, ' Female')
# (23, ' Male')
# (38, ' Female')
# (62, ' Male')
# (65, ' Female')
# (40, ' Male')
# (43, ' Male')
# (43, ' Female')
# (32, ' Female')
# (31, ' Male')
# (41, ' Female')
# (43, ' Female')
# (27, ' Female')
# (45, ' Female')
# (48, ' Male')
# (47, ' Male')
# (35, ' Female')
# (54, ' Male')
# (34, ' Female')
# (55, ' Female')
# (42, ' Male')
# (59, ' Male')
# (30, ' Male')
# (27, ' Male')
# (44, ' Female')
# (38, ' Female')
# (24, ' Male')
# (36, ' Female')
# (53, ' Male')
# (35, ' Male')
# (23, ' Female')
# (48, ' Male')
# (44, ' Female')
# (19, ' Female')
# (51, ' Male')
# (50, ' Male')
# (41, ' Male')
# (61, ' Female')
# (41, ' Male')
# (47, ' Female')
# (52, ' Male')
# (68, ' Female')
# (38, ' Female')
# (35, ' Female')
# (38, ' Male')
# (54, ' Female')
# (41, ' Female')
# (41, ' Female')
# (44, ' Male')
# (47, ' Female')
# (28, ' Female')
# (32, ' Female')
# (42, ' Male')
# (36, ' Female')
# (40, ' Male')
# (40, ' Female')
# (55, ' Female')
# (36, ' Female')
# (41, ' Female')
# (36, ' Female')
# (50, ' Male')
# (39, ' Female')
# (42, ' Male')
# (36, ' Male')
# (45, ' Female')
# (45, ' Female')
# (43, ' Male')
# (47, ' Female')
# (57, ' Male')
# (27, ' Male')
# (33, ' Female')
# (36, ' Male')
# (42, ' Male')
# (33, ' Male')
# (49, ' Male')
# (31, ' Male')
# (32, ' Female')
# (61, ' Male')
# (29, ' Female')
# (27, ' Female')
# (62, ' Female')
# (33, ' Female')
# (61, ' Female')
# (31, ' Female')
# (26, ' Female')
# (33, ' Male')
# (54, ' Male')
# (36, ' Male')
# (41, ' Male')
# (56, ' Male')
# (46, ' Male')
# (43, ' Male')
# (46, ' Male')
# (30, ' Male')
# (43, ' Female')
# (28, ' Male')
# (42, ' Female')
# (39, ' Female')
# (45, ' Female')
# (35, ' Male')
# (38, ' Male')
# (47, ' Female')
# (37, ' Female')
# (31, ' Female')
# (61, ' Female')
# (47, ' Female')
# (46, ' Female')
# (33, ' Female')
# (34, ' Female')
# (38, ' Female')
# (62, ' Male')
# (49, ' Female')
# (54, ' Male')
# (48, ' Female')
# (40, ' Female')
# (53, ' Male')
# (53, ' Female')
# (29, ' Male')
# (31, ' Female')
# (39, ' Female')
# (38, ' Female')
# (43, ' Female')
# (42, ' Female')
# (39, ' Male')
# (61, ' Female')
# (37, ' Female')
# (28, ' Female')
# (42, ' Female')
# (55, ' Female')
# (37, ' Female')
# (43, ' Male')
# (35, ' Male')
# (39, ' Female')
# (47, ' Female')
# (60, ' Male')
# (36, ' Female')
# (50, ' Female')
# (49, ' Male')
# (63, ' Female')
# (42, ' Female')
# (59, ' Female')
# (59, ' Female')
# (45, ' Female')
# (33, ' Female')
# (38, ' Female')
# (44, ' Male')
# (29, ' Male')
# (37, ' Female')
# (38, ' Female')
# (42, ' Male')
# (46, ' Female')
# (27, ' Male')
# (43, ' Male')
# (40, ' Female')
# (24, ' Female')
# (37, ' Female')
# (54, ' Female')
# (47, ' Male')
# (34, ' Female')
# (38, ' Male')
# (71, ' Female')
# (41, ' Male')
# (39, ' Male')
# (36, ' Female')
# (41, ' Female')
# (36, ' Male')
# (32, ' Female')
# (50, ' Female')
# (33, ' Female')
# (45, ' Female')
# (45, ' Female')
# (30, ' Male')
# (35, ' Female')
# (50, ' Male')
# (47, ' Male')
# (38, ' Male')
# (55, ' Female')
# (43, ' Male')
# (69, ' Female')
# (38, ' Female')
# (32, ' Female')
# (43, ' Male')
# (59, ' Female')
# (57, ' Male')
# (43, ' Male')
# (38, ' Male')
# (43, ' Female')
# (35, ' Female')
# (36, ' Female')
# (29, ' Female')
# (39, ' Male')
# (46, ' Female')
# (63, ' Male')
# (38, ' Female')
# (50, ' Female')
# (42, ' Male')
# (41, ' Female')
# (45, ' Male')
# (46, ' Female')
# (48, ' Female')
# (33, ' Female')
# (58, ' Female')
# (36, ' Female')
# (39, ' Male')
# (45, ' Male')
# (41, ' Female')
# (34, ' Female')
# (47, ' Female')
# (34, ' Female')
# (37, ' Female')
# (51, ' Female')
# (42, ' Male')
# (31, ' Female')
# (40, ' Male')
# (59, ' Male')
# (53, ' Female')
# (39, ' Female')
# (43, ' Male')
# (39, ' Female')
# (31, ' Male')
# (58, ' Female')
# (33, ' Male')
# (31, ' Female')
# (60, ' Male')
# (51, ' Female')
# (32, ' Male')
# (22, ' Female')
# (63, ' Female')
# (36, ' Female')
# (43, ' Female')
# (53, ' Male')
# (32, ' Female')
# (35, ' Female')
# (46, ' Female')
# (62, ' Female')
# (56, ' Male')
# (41, ' Female')
# (46, ' Male')
# (30, ' Female')
# (56, ' Female')
# (42, ' Female')
# (48, ' Female')
# (33, ' Female')
# (30, ' Female')
# (54, ' Male')
# (51, ' Male')
# (32, ' Female')
# (61, ' Female')
# (32, ' Female')
# (29, ' Female')
# (43, ' Male')
# (27, ' Female')
# (74, ' Female')
# (39, ' Female')
# (38, ' Female')
# (51, ' Male')
# (36, ' Male')
# (38, ' Male')
# (44, ' Female')
# (46, ' Male')
# (43, ' Male')
# (48, ' Male')
# (64, ' Male')
# (38, ' Male')
# (42, ' Male')
# (29, ' Female')
# (41, ' Female')
# (30, ' Female')
# (30, ' Male')
# (48, ' Male')
# (44, ' Female')
# (34, ' Male')
# (51, ' Male')
# (55, ' Female')
# (39, ' Female')
# (31, ' Male')
# (27, ' Male')
# (45, ' Male')
# (37, ' Female')
# (45, ' Female')
# (41, ' Female')
# (64, ' Male')
# (34, ' Female')
# (52, ' Female')
# (38, ' Female')
# (45, ' Female')
# (26, ' Male')
# (44, ' Male')
# (36, ' Male')
# (47, ' Male')
# (34, ' Male')
# (67, ' Female')
# (42, ' Male')
# (41, ' Male')
# (45, ' Female')
# (69, ' Female')
# (48, ' Female')
# (36, ' Female')
# (52, ' Female')
# (25, ' Female')
# (47, ' Female')
# (46, ' Female')
# (32, ' Male')
# (33, ' Male')
# (61, ' Female')
# (24, ' Female')
# (32, ' Female')
# (47, ' Female')
# (40, ' Female')
# (50, ' Female')
# (36, ' Female')
# (30, ' Female')
# (35, ' Female')
# (49, ' Female')
# (40, ' Female')
# (49, ' Female')
# (34, ' Female')
# (38, ' Female')
# (23, ' Female')
# (48, ' Male')
# (43, ' Female')
# (36, ' Male')
# (50, ' Female')
# (40, ' Female')
# (38, ' Female')
# (44, ' Female')
# (49, ' Male')
# (33, ' Female')
# (35, ' Female')
# (41, ' Female')
# (36, ' Female')
# (31, ' Male')
# (46, ' Female')
# (55, ' Male')
# (56, ' Female')
# (35, ' Female')
# (34, ' Female')
# (42, ' Female')
# (38, ' Male')
# (36, ' Female')
# (51, ' Male')
# (52, ' Female')
# (41, ' Female')
# (34, ' Male')
# (40, ' Female')
# (44, ' Female')
# (52, ' Male')
# (42, ' Female')
# (35, ' Female')
# (38, ' Male')
# (43, ' Male')
# (56, ' Female')
# (41, ' Male')
# (36, ' Male')
# (42, ' Female')
# (45, ' Female')
# (43, ' Male')
# (34, ' Female')
# (43, ' Female')
# (37, ' Female')
# (52, ' Female')
# (45, ' Female')
# (39, ' Female')
# (28, ' Female')
# (38, ' Male')
# (52, ' Female')
# (47, ' Male')
# (60, ' Male')
# (57, ' Female')
# (41, ' Male')
# (51, ' Female')
# (55, ' Female')
# (40, ' Male')
# (52, ' Male')
# (37, ' Male')
# (45, ' Male')
# (39, ' Female')
# (50, ' Female')
# (41, ' Female')
# (49, ' Female')
# (42, ' Male')
# (52, ' Male')
# (36, ' Male')
# (47, ' Female')
# (31, ' Female')
# (42, ' Female')
# (36, ' Male')
# (42, ' Female')
# (54, ' Male')
# (46, ' Male')
# (39, ' Female')
# (39, ' Male')
# (34, ' Female')
# (34, ' Male')
# (55, ' Female')
# (38, ' Female')
# (28, ' Male')
# (37, ' Male')
# (57, ' Male')
# (41, ' Male')
# (36, ' Male')
# (45, ' Female')
# (31, ' Male')
# (43, ' Female')
# (43, ' Female')
# (35, ' Male')
# (40, ' Male')
# (41, ' Female')
# (66, ' Female')
# (21, ' Female')
# (51, ' Male')
# (44, ' Female')
# (29, ' Female')
# (46, ' Female')
# (42, ' Male')
# (39, ' Female')
# (57, ' Male')
# (47, ' Female')
# (43, ' Female')
# (47, ' Female')
# (35, ' Female')
# (56, ' Female')
# (38, ' Male')
# (65, ' Male')
# (42, ' Male')
# (36, ' Female')
# (62, ' Male')
# (38, ' Female')
# (49, ' Male')
# (60, ' Female')
# (36, ' Female')
# (43, ' Male')
# (29, ' Female')
# (46, ' Female')
# (57, ' Female')
# (54, ' Male')
# (50, ' Female')
# (43, ' Female')
# (36, ' Female')
# (46, ' Female')
# (42, ' Male')
# (35, ' Female')
# (38, ' Male')
# (31, ' Male')
# (51, ' Female')
# (57, ' Female')
# (30, ' Male')
# (50, ' Female')
# (32, ' Female')
# (25, ' Female')
# (41, ' Male')
# (33, ' Female')
# (31, ' Female')
# (45, ' Female')
# (48, ' Female')
# (48, ' Female')
# (44, ' Male')
# (43, ' Male')
# (31, ' Male')
# (60, ' Female')
# (57, ' Female')
# (31, ' Male')
# (50, ' Male')
# (48, ' Male')
# (53, ' Female')
# (53, ' Female')
# (39, ' Male')
# (43, ' Female')
# (41, ' Female')
# (55, ' Female')
# (44, ' Female')
# (62, ' Female')
# (33, ' Male')
# (46, ' Female')
# (31, ' Female')
# (41, ' Male')
# (57, ' Male')
# (50, ' Female')
# (41, ' Female')
# (35, ' Male')
# (30, ' Female')
# (29, ' Male')
# (29, ' Male')
# (42, ' Male')
# (34, ' Female')
# (39, ' Female')
# (48, ' Female')
# (44, ' Male')
# (26, ' Male')
# (30, ' Female')
# (29, ' Male')
# (42, ' Female')
# (42, ' Male')
# (43, ' Female')
# (27, ' Female')
# (50, ' Male')
# (28, ' Female')
# (46, ' Male')
# (39, ' Male')
# (41, ' Male')
# (46, ' Female')
# (44, ' Female')
# (27, ' Female')
# (35, ' Female')
# (44, ' Female')
# (40, ' Male')
# (48, ' Female')
# (40, ' Female')
# (41, ' Male')
# (23, ' Female')
# (48, ' Female')
# (46, ' Female')
# (33, ' Female')
# (42, ' Female')
# (29, ' Male')
# (23, ' Male')
# (39, ' Female')
# (42, ' Male')
# (26, ' Female')
# (42, ' Female')
# (40, ' Male')
# (36, ' Female')
# (38, ' Female')
# (49, ' Female')
# (56, ' Female')
# (25, ' Male')
# (74, ' Female')
# (50, ' Female')
# (43, ' Female')
# (51, ' Female')
# (54, ' Female')
# (32, ' Female')
# (61, ' Female')
# (53, ' Female')
# (45, ' Female')
# (36, ' Female')
# (61, ' Female')
# (28, ' Female')
# (39, ' Female')
# (45, ' Female')
# (30, ' Female')
# (40, ' Female')
# (57, ' Male')
# (42, ' Female')
# (37, ' Female')
# (36, ' Male')
# (32, ' Male')
# (63, ' Female')
# (53, ' Female')
# (44, ' Female')
# (36, ' Female')
# (42, ' Male')
# (41, ' Female')
# (31, ' Female')
# (39, ' Female')
# (60, ' Female')
# (27, ' Male')
# (59, ' Male')
# (46, ' Female')
# (37, ' Male')
# (46, ' Male')
# (55, ' Female')
# (34, ' Female')
# (24, ' Female')
# (44, ' Male')
# (68, ' Female')
# (46, ' Female')
# (45, ' Male')
# (33, ' Male')
# (37, ' Female')
# (44, ' Male')
# (42, ' Male')
# (48, ' Male')
# (25, ' Male')
# (42, ' Male')
# (52, ' Female')
# (50, ' Female')
# (38, ' Female')
# (53, ' Male')
# (46, ' Female')
# (56, ' Male')
# (53, ' Female')
# (49, ' Female')
# (51, ' Female')
# (61, ' Female')
# (45, ' Male')
# (55, ' Female')
# (33, ' Male')
# (37, ' Male')
# (49, ' Male')
# (48, ' Female')
# (29, ' Female')
# (39, ' Male')
# (42, ' Female')
# (40, ' Male')
# (46, ' Male')
# (68, ' Male')
# (53, ' Male')
# (45, ' Female')
# (55, ' Male')
# (31, ' Female')
# (56, ' Female')
# (44, ' Female')
# (47, ' Male')
# (45, ' Male')
# (58, ' Female')
# (31, ' Male')
# (55, ' Female')
# (49, ' Female')
# (29, ' Female')
# (42, ' Female')
# (44, ' Female')
# (59, ' Male')
# (54, ' Female')
# (41, ' Male')
# (63, ' Female')
# (42, ' Male')
# (31, ' Male')
# (50, ' Female')
# (33, ' Female')
# (36, ' Male')
# (35, ' Female')
# (35, ' Female')
# (40, ' Female')
# (48, ' Female')
# (44, ' Female')
# (31, ' Male')
# (56, ' Female')
# (35, ' Female')
# (61, ' Male')
# (29, ' Female')
# (47, ' Female')
# (41, ' Female')
# (51, ' Female')
# (50, ' Female')
# (50, ' Female')
# (28, ' Male')
# (41, ' Female')
# (49, ' Male')
# (48, ' Female')
# (60, ' Male')
# (33, ' Female')
# (42, ' Male')
# (50, ' Female')
# (45, ' Female')
# (30, ' Female')
# (30, ' Male')
# (81, ' Female')
# (37, ' Female')
# (38, ' Female')
# (45, ' Female')
# (31, ' Female')
# (37, ' Female')
# (43, ' Female')

# %% [markdown]
# ## 5. Write two function queries

# %%
fn1 = engine.execute('''select sex,max(age), min(age), avg(age) from adult group by(sex)''')
for row in fn1:
    print (row)
#average Divorcing age on available adult data
# Out:
# (' Female', 90, 17, 36.80115618459085)
# (' Male', 90, 17, 39.37003225006202)

# %%
fn2 = engine.execute('''select native_country,count(sex=" Male"), count(sex=" Female") from adult group by(native_country)''')
for row in fn2:
    print (row)
#count of male & female w.r.t country
# Out:
# (' ?', 535, 535)
# (' Cambodia', 16, 16)
# (' Canada', 113, 113)
# (' China', 69, 69)
# (' Columbia', 54, 54)
# (' Cuba', 81, 81)
# (' Dominican-Republic', 47, 47)
# (' Ecuador', 25, 25)
# (' El-Salvador', 64, 64)
# (' England', 87, 87)
# (' France', 29, 29)
# (' Germany', 131, 131)
# (' Greece', 25, 25)
# (' Guatemala', 33, 33)
# (' Haiti', 37, 37)
# (' Holand-Netherlands', 1, 1)
# (' Honduras', 9, 9)
# (' Hong', 17, 17)
# (' Hungary', 13, 13)
# (' India', 93, 93)
# (' Iran', 43, 43)
# (' Ireland', 23, 23)
# (' Italy', 55, 55)
# (' Jamaica', 76, 76)
# (' Japan', 62, 62)
# (' Laos', 13, 13)
# (' Mexico', 335, 335)
# (' Nicaragua', 27, 27)
# (' Outlying-US(Guam-USVI-etc)', 14, 14)
# (' Peru', 27, 27)
# (' Philippines', 181, 181)
# (' Poland', 54, 54)
# (' Portugal', 24, 24)
# (' Puerto-Rico', 85, 85)
# (' Scotland', 11, 11)
# (' South', 76, 76)
# (' Taiwan', 51, 51)
# (' Thailand', 18, 18)
# (' Trinadad&Tobago', 16, 16)
# (' United-States', 27444, 27444)
# (' Vietnam', 59, 59)
# (' Yugoslavia', 15, 15)
